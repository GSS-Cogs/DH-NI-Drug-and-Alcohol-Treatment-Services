# %% [markdown]
# Census of Drug and Alcohol Treatment Services in Northern Ireland:Table 3 – Breakdown by Category

# %%
from gssutils import *
if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
    inputFile = sourceFolder / 'data-census-drug-alcohol-treatment-services.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 3')[0]
# Out:
# Loading in\data-census-drug-alcohol-treatment-services.xlsx which has size 46265 bytes
# Table names: ['Table 3']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B12').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<C7 1441.0>, <K10 97.8>, <C8 33.0>, <E11 4.5>, <D6 204.0>, <J8 7.0>, <C5 1496.0>, <L5 1689.0>, <E9 0.0>, <G8 148.0>, <K8 63.0>, <L10 91.6>, <F11 3.5>, <M8 63.0>, <F5 3567.0>, <D9 19.8>, <H5 1010.0>, <D7 784.0>, <C10 96.3>, <D10 76.0>, <I10 96.9>, <G7 3613.0>, <E7 504.0>, <F6 334.0>, <H6 57.0>, <L7 1547.0>, <I6 5.0>, <I8 12.0>, <B9 6.9>, <E10 95.5>, <F9 9.4>, <D11 4.3>, <E8 24.0>, <E6 0.0>, <H8 44.0>, <G10 88.2>, <M7 1728.0>, <M10 92.2>, <M6 83.0>, <B7 1388.0>, <K6 83.0>, <G6 334.0>, <I9 0.9>, <F8 124.0>, <J9 6.5>, <K5 185.0>, <B5 1567.0>, <C11 2.2>, <I11 2.2>, <H9 5.6>, <E5 528.0>, <I7 523.0>, <D5 1032.0>, <G5 4095.0>, <K9 4.4>, <M5 1874.0>, <B10 88.6>, <H10 90.0>, <B8 71.0>, <F10 87.2>, <F7 3109.0>, <C9 1.5>, <C6 22.0>, <J11 2.2>, <I5 540.0>, <H11 4.4>, <J5 324.0>, <J7 296.0>, <B11 4.5>, <D8 44.0>, <J6 21.0>, <G9 8.2>, <B6 108.0>, <K7 181.0>, <M11 3.4>, <H7 909.0>, <G11 3.6>, <M9 4.4>, <K11 3.4>, <J10 91.4>}

# %%
Service = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Service
# Out:
# {<A20 'Non-residential (%)'>, <A9 'Residential (%)'>, <A17 'Non-residential '>, <A21 'Mixed (%)'>, <A11 'Mixed (%)'>, <A10 'Non-residential (%)'>, <A19 'Residential (%)'>, <A13 'Residential Status'>, <A7 'Non-residential '>, <A6 'Residential'>, <A16 'Residential'>, <A18 'Mixed'>, <A15 'Total'>, <A5 'Total'>, <A8 'Mixed'>}

# %%
Treatment = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Treatment
# Out:
# {<M4 'Total'>, <G4 'Total'>, <D4 'Drugs & Alcohol'>, <C4 'Drugs Only'>, <K4 'Under 18s'>, <I4 'Drugs Only'>, <F4 '18 and over'>, <J4 'Drugs & Alcohol'>, <E4 'Under 18s'>, <L4 '18 and over'>, <B4 'Alcohol Only'>, <H4 'Alcohol Only'>}

# %%
sex = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
sex
# Out:
# {<H3 'Female  '>, <B3 'Male'>}

# %%
Dimensions = [
            HDim(Treatment,'Treatment Type',DIRECTLY,ABOVE),
            HDim(Service,'Category',DIRECTLY,LEFT),
            HDim(sex,'Sex',CLOSEST,LEFT),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Age','All'),
            HDimConst('Period', '1 March 2017')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS   Treatment Type             Category       Sex Measure Type  \
# 0   1567.0     Alcohol Only                Total      Male        Count
# 1   1496.0       Drugs Only                Total      Male        Count
# 2   1032.0  Drugs & Alcohol                Total      Male        Count
# 3    528.0        Under 18s                Total      Male        Count
# 4   3567.0      18 and over                Total      Male        Count
# 5   4095.0            Total                Total      Male        Count
# 6   1010.0     Alcohol Only                Total  Female          Count
# 7    540.0       Drugs Only                Total  Female          Count
# 8    324.0  Drugs & Alcohol                Total  Female          Count
# 9    185.0        Under 18s                Total  Female          Count
# 10  1689.0      18 and over                Total  Female          Count
# 11  1874.0            Total                Total  Female          Count
# 12   108.0     Alcohol Only          Residential      Male        Count
# 13    22.0       Drugs Only          Residential      Male        Count
# 14   204.0  Drugs & Alcohol          Residential      Male        Count
# 15     0.0        Under 18s          Residential      Male        Count
# 16   334.0      18 and over          Residential      Male        Count
# 17   334.0            Total          Residential      Male        Count
# 18    57.0     Alcohol Only          Residential  Female          Count
# 19     5.0       Drugs Only          Residential  Female          Count
# 20    21.0  Drugs & Alcohol          Residential  Female          Count
# 21    83.0        Under 18s          Residential  Female          Count
# 22    83.0            Total          Residential  Female          Count
# 23  1388.0     Alcohol Only     Non-residential       Male        Count
# 24  1441.0       Drugs Only     Non-residential       Male        Count
# 25   784.0  Drugs & Alcohol     Non-residential       Male        Count
# 26   504.0        Under 18s     Non-residential       Male        Count
# 27  3109.0      18 and over     Non-residential       Male        Count
# 28  3613.0            Total     Non-residential       Male        Count
# 29   909.0     Alcohol Only     Non-residential   Female          Count
# ..     ...              ...                  ...       ...          ...
# 50     9.4      18 and over      Residential (%)      Male        Count
# 51     8.2            Total      Residential (%)      Male        Count
# 52     5.6     Alcohol Only      Residential (%)  Female          Count
# 53     0.9       Drugs Only      Residential (%)  Female          Count
# 54     6.5  Drugs & Alcohol      Residential (%)  Female          Count
# 55     4.4        Under 18s      Residential (%)  Female          Count
# 56     4.4            Total      Residential (%)  Female          Count
# 57    88.6     Alcohol Only  Non-residential (%)      Male        Count
# 58    96.3       Drugs Only  Non-residential (%)      Male        Count
# 59    76.0  Drugs & Alcohol  Non-residential (%)      Male        Count
# 60    95.5        Under 18s  Non-residential (%)      Male        Count
# 61    87.2      18 and over  Non-residential (%)      Male        Count
# 62    88.2            Total  Non-residential (%)      Male        Count
# 63    90.0     Alcohol Only  Non-residential (%)  Female          Count
# 64    96.9       Drugs Only  Non-residential (%)  Female          Count
# 65    91.4  Drugs & Alcohol  Non-residential (%)  Female          Count
# 66    97.8        Under 18s  Non-residential (%)  Female          Count
# 67    91.6      18 and over  Non-residential (%)  Female          Count
# 68    92.2            Total  Non-residential (%)  Female          Count
# 69     4.5     Alcohol Only            Mixed (%)      Male        Count
# 70     2.2       Drugs Only            Mixed (%)      Male        Count
# 71     4.3  Drugs & Alcohol            Mixed (%)      Male        Count
# 72     4.5        Under 18s            Mixed (%)      Male        Count
# 73     3.5      18 and over            Mixed (%)      Male        Count
# 74     3.6            Total            Mixed (%)      Male        Count
# 75     4.4     Alcohol Only            Mixed (%)  Female          Count
# 76     2.2       Drugs Only            Mixed (%)  Female          Count
# 77     2.2  Drugs & Alcohol            Mixed (%)  Female          Count
# 78     3.4        Under 18s            Mixed (%)  Female          Count
# 79     3.4            Total            Mixed (%)  Female          Count
#
#       Unit  Age        Period
# 0   People  All  1 March 2017
# 1   People  All  1 March 2017
# 2   People  All  1 March 2017
# 3   People  All  1 March 2017
# 4   People  All  1 March 2017
# 5   People  All  1 March 2017
# 6   People  All  1 March 2017
# 7   People  All  1 March 2017
# 8   People  All  1 March 2017
# 9   People  All  1 March 2017
# 10  People  All  1 March 2017
# 11  People  All  1 March 2017
# 12  People  All  1 March 2017
# 13  People  All  1 March 2017
# 14  People  All  1 March 2017
# 15  People  All  1 March 2017
# 16  People  All  1 March 2017
# 17  People  All  1 March 2017
# 18  People  All  1 March 2017
# 19  People  All  1 March 2017
# 20  People  All  1 March 2017
# 21  People  All  1 March 2017
# 22  People  All  1 March 2017
# 23  People  All  1 March 2017
# 24  People  All  1 March 2017
# 25  People  All  1 March 2017
# 26  People  All  1 March 2017
# 27  People  All  1 March 2017
# 28  People  All  1 March 2017
# 29  People  All  1 March 2017
# ..     ...  ...           ...
# 50  People  All  1 March 2017
# 51  People  All  1 March 2017
# 52  People  All  1 March 2017
# 53  People  All  1 March 2017
# 54  People  All  1 March 2017
# 55  People  All  1 March 2017
# 56  People  All  1 March 2017
# 57  People  All  1 March 2017
# 58  People  All  1 March 2017
# 59  People  All  1 March 2017
# 60  People  All  1 March 2017
# 61  People  All  1 March 2017
# 62  People  All  1 March 2017
# 63  People  All  1 March 2017
# 64  People  All  1 March 2017
# 65  People  All  1 March 2017
# 66  People  All  1 March 2017
# 67  People  All  1 March 2017
# 68  People  All  1 March 2017
# 69  People  All  1 March 2017
# 70  People  All  1 March 2017
# 71  People  All  1 March 2017
# 72  People  All  1 March 2017
# 73  People  All  1 March 2017
# 74  People  All  1 March 2017
# 75  People  All  1 March 2017
# 76  People  All  1 March 2017
# 77  People  All  1 March 2017
# 78  People  All  1 March 2017
# 79  People  All  1 March 2017
#
# [80 rows x 8 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Category           object
# Sex                object
# Measure Type       object
# Unit               object
# Age                object
# Period             object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value   Treatment Type   Category       Sex Measure Type    Unit  Age  \
# 75    4.4     Alcohol Only  Mixed (%)  Female          Count  People  All
# 76    2.2       Drugs Only  Mixed (%)  Female          Count  People  All
# 77    2.2  Drugs & Alcohol  Mixed (%)  Female          Count  People  All
# 78    3.4        Under 18s  Mixed (%)  Female          Count  People  All
# 79    3.4            Total  Mixed (%)  Female          Count  People  All
#
#           Period
# 75  1 March 2017
# 76  1 March 2017
# 77  1 March 2017
# 78  1 March 2017
# 79  1 March 2017

# %%
new_table.count()
# Out:
# Value             80
# Treatment Type    80
# Category          80
# Sex               80
# Measure Type      80
# Unit              80
# Age               80
# Period            80
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value             78
# Treatment Type    78
# Category          78
# Sex               78
# Measure Type      78
# Unit              78
# Age               78
# Period            78
# dtype: int64

# %%
new_table = new_table[['Period','Category','Age','Sex','Treatment Type','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#          Period Category  Age   Sex   Treatment Type Measure Type   Value  \
# 0  1 March 2017    Total  All  Male     Alcohol Only        Count  1567.0
# 1  1 March 2017    Total  All  Male       Drugs Only        Count  1496.0
# 2  1 March 2017    Total  All  Male  Drugs & Alcohol        Count  1032.0
# 3  1 March 2017    Total  All  Male        Under 18s        Count   528.0
# 4  1 March 2017    Total  All  Male      18 and over        Count  3567.0
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

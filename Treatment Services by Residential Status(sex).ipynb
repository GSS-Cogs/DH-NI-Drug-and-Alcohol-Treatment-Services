# %% [markdown]
# Census of Drug and Alcohol Treatment Services in Northern Ireland:Table 3 – Breakdown by Residential Status

# %%
from gssutils import *
if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
    inputFile = sourceFolder / 'data-census-drug-alcohol-treatment-services.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 3')[0]
# Out:
# Loading in/data-census-drug-alcohol-treatment-services.xlsx which has size 46265 bytes
# Table names: ['Table 3']

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B12').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<D11 4.3>, <H8 44.0>, <M7 1728.0>, <M6 83.0>, <B7 1388.0>, <I9 0.9>, <G6 334.0>, <J9 6.5>, <C11 2.2>, <I11 2.2>, <H9 5.6>, <F7 3109.0>, <I7 523.0>, <K9 4.4>, <H11 4.4>, <J7 296.0>, <B11 4.5>, <B10 88.6>, <H10 90.0>, <H7 909.0>, <C9 1.5>, <E9 0.0>, <F10 87.2>, <G9 8.2>, <C6 22.0>, <J11 2.2>, <M9 4.4>, <B8 71.0>, <J10 91.4>, <C7 1441.0>, <E10 95.5>, <K7 181.0>, <C8 33.0>, <K11 3.4>, <D8 44.0>, <J6 21.0>, <E11 4.5>, <G11 3.6>, <D7 784.0>, <D6 204.0>, <J8 7.0>, <M11 3.4>, <G8 148.0>, <K10 97.8>, <M8 63.0>, <F11 3.5>, <D9 19.8>, <C10 96.3>, <B6 108.0>, <I10 96.9>, <G7 3613.0>, <K8 63.0>, <L10 91.6>, <L7 1547.0>, <I6 5.0>, <B9 6.9>, <D10 76.0>, <I8 12.0>, <E7 504.0>, <F6 334.0>, <F9 9.4>, <H6 57.0>, <K6 83.0>, <E8 24.0>, <M10 92.2>, <E6 0.0>, <G10 88.2>, <F8 124.0>}

# %%
Service = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Service
# Out:
# {<A9 'Residential (%)'>, <A13 'Residential Status'>, <A21 'Mixed (%)'>, <A10 'Non-residential (%)'>, <A7 'Non-residential '>, <A11 'Mixed (%)'>, <A15 'Total'>, <A17 'Non-residential '>, <A5 'Total'>, <A19 'Residential (%)'>, <A16 'Residential'>, <A6 'Residential'>, <A20 'Non-residential (%)'>, <A8 'Mixed'>, <A18 'Mixed'>}

# %%
Treatment = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Treatment
# Out:
# {<D4 'Drugs & Alcohol'>, <J4 'Drugs & Alcohol'>, <L4 '18 and over'>, <E4 'Under 18s'>, <H4 'Alcohol Only'>, <M4 'Total'>, <B4 'Alcohol Only'>, <K4 'Under 18s'>, <I4 'Drugs Only'>, <G4 'Total'>, <C4 'Drugs Only'>, <F4 '18 and over'>}

# %%
sex = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
sex
# Out:
# {<H3 'Female  '>, <B3 'Male'>}

# %%
Dimensions = [
            HDim(Treatment,'Treatment Type',DIRECTLY,ABOVE),
            HDim(Service,'Residential Status',DIRECTLY,LEFT),
            HDim(sex,'Sex',CLOSEST,LEFT),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Age','All'),
            HDimConst('Period', '1 March 2017')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS   Treatment Type   Residential Status       Sex Measure Type  \
# 0    108.0     Alcohol Only          Residential      Male        Count
# 1     22.0       Drugs Only          Residential      Male        Count
# 2    204.0  Drugs & Alcohol          Residential      Male        Count
# 3      0.0        Under 18s          Residential      Male        Count
# 4    334.0      18 and over          Residential      Male        Count
# 5    334.0            Total          Residential      Male        Count
# 6     57.0     Alcohol Only          Residential  Female          Count
# 7      5.0       Drugs Only          Residential  Female          Count
# 8     21.0  Drugs & Alcohol          Residential  Female          Count
# 9     83.0        Under 18s          Residential  Female          Count
# 10    83.0            Total          Residential  Female          Count
# 11  1388.0     Alcohol Only     Non-residential       Male        Count
# 12  1441.0       Drugs Only     Non-residential       Male        Count
# 13   784.0  Drugs & Alcohol     Non-residential       Male        Count
# 14   504.0        Under 18s     Non-residential       Male        Count
# 15  3109.0      18 and over     Non-residential       Male        Count
# 16  3613.0            Total     Non-residential       Male        Count
# 17   909.0     Alcohol Only     Non-residential   Female          Count
# 18   523.0       Drugs Only     Non-residential   Female          Count
# 19   296.0  Drugs & Alcohol     Non-residential   Female          Count
# 20   181.0        Under 18s     Non-residential   Female          Count
# 21  1547.0      18 and over     Non-residential   Female          Count
# 22  1728.0            Total     Non-residential   Female          Count
# 23    71.0     Alcohol Only                Mixed      Male        Count
# 24    33.0       Drugs Only                Mixed      Male        Count
# 25    44.0  Drugs & Alcohol                Mixed      Male        Count
# 26    24.0        Under 18s                Mixed      Male        Count
# 27   124.0      18 and over                Mixed      Male        Count
# 28   148.0            Total                Mixed      Male        Count
# 29    44.0     Alcohol Only                Mixed  Female          Count
# ..     ...              ...                  ...       ...          ...
# 38     9.4      18 and over      Residential (%)      Male        Count
# 39     8.2            Total      Residential (%)      Male        Count
# 40     5.6     Alcohol Only      Residential (%)  Female          Count
# 41     0.9       Drugs Only      Residential (%)  Female          Count
# 42     6.5  Drugs & Alcohol      Residential (%)  Female          Count
# 43     4.4        Under 18s      Residential (%)  Female          Count
# 44     4.4            Total      Residential (%)  Female          Count
# 45    88.6     Alcohol Only  Non-residential (%)      Male        Count
# 46    96.3       Drugs Only  Non-residential (%)      Male        Count
# 47    76.0  Drugs & Alcohol  Non-residential (%)      Male        Count
# 48    95.5        Under 18s  Non-residential (%)      Male        Count
# 49    87.2      18 and over  Non-residential (%)      Male        Count
# 50    88.2            Total  Non-residential (%)      Male        Count
# 51    90.0     Alcohol Only  Non-residential (%)  Female          Count
# 52    96.9       Drugs Only  Non-residential (%)  Female          Count
# 53    91.4  Drugs & Alcohol  Non-residential (%)  Female          Count
# 54    97.8        Under 18s  Non-residential (%)  Female          Count
# 55    91.6      18 and over  Non-residential (%)  Female          Count
# 56    92.2            Total  Non-residential (%)  Female          Count
# 57     4.5     Alcohol Only            Mixed (%)      Male        Count
# 58     2.2       Drugs Only            Mixed (%)      Male        Count
# 59     4.3  Drugs & Alcohol            Mixed (%)      Male        Count
# 60     4.5        Under 18s            Mixed (%)      Male        Count
# 61     3.5      18 and over            Mixed (%)      Male        Count
# 62     3.6            Total            Mixed (%)      Male        Count
# 63     4.4     Alcohol Only            Mixed (%)  Female          Count
# 64     2.2       Drugs Only            Mixed (%)  Female          Count
# 65     2.2  Drugs & Alcohol            Mixed (%)  Female          Count
# 66     3.4        Under 18s            Mixed (%)  Female          Count
# 67     3.4            Total            Mixed (%)  Female          Count
#
#       Unit  Age        Period
# 0   People  All  1 March 2017
# 1   People  All  1 March 2017
# 2   People  All  1 March 2017
# 3   People  All  1 March 2017
# 4   People  All  1 March 2017
# 5   People  All  1 March 2017
# 6   People  All  1 March 2017
# 7   People  All  1 March 2017
# 8   People  All  1 March 2017
# 9   People  All  1 March 2017
# 10  People  All  1 March 2017
# 11  People  All  1 March 2017
# 12  People  All  1 March 2017
# 13  People  All  1 March 2017
# 14  People  All  1 March 2017
# 15  People  All  1 March 2017
# 16  People  All  1 March 2017
# 17  People  All  1 March 2017
# 18  People  All  1 March 2017
# 19  People  All  1 March 2017
# 20  People  All  1 March 2017
# 21  People  All  1 March 2017
# 22  People  All  1 March 2017
# 23  People  All  1 March 2017
# 24  People  All  1 March 2017
# 25  People  All  1 March 2017
# 26  People  All  1 March 2017
# 27  People  All  1 March 2017
# 28  People  All  1 March 2017
# 29  People  All  1 March 2017
# ..     ...  ...           ...
# 38  People  All  1 March 2017
# 39  People  All  1 March 2017
# 40  People  All  1 March 2017
# 41  People  All  1 March 2017
# 42  People  All  1 March 2017
# 43  People  All  1 March 2017
# 44  People  All  1 March 2017
# 45  People  All  1 March 2017
# 46  People  All  1 March 2017
# 47  People  All  1 March 2017
# 48  People  All  1 March 2017
# 49  People  All  1 March 2017
# 50  People  All  1 March 2017
# 51  People  All  1 March 2017
# 52  People  All  1 March 2017
# 53  People  All  1 March 2017
# 54  People  All  1 March 2017
# 55  People  All  1 March 2017
# 56  People  All  1 March 2017
# 57  People  All  1 March 2017
# 58  People  All  1 March 2017
# 59  People  All  1 March 2017
# 60  People  All  1 March 2017
# 61  People  All  1 March 2017
# 62  People  All  1 March 2017
# 63  People  All  1 March 2017
# 64  People  All  1 March 2017
# 65  People  All  1 March 2017
# 66  People  All  1 March 2017
# 67  People  All  1 March 2017
#
# [68 rows x 8 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value                 float64
# Treatment Type         object
# Residential Status     object
# Sex                    object
# Measure Type           object
# Unit                   object
# Age                    object
# Period                 object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value   Treatment Type Residential Status       Sex Measure Type    Unit  \
# 63    4.4     Alcohol Only          Mixed (%)  Female          Count  People
# 64    2.2       Drugs Only          Mixed (%)  Female          Count  People
# 65    2.2  Drugs & Alcohol          Mixed (%)  Female          Count  People
# 66    3.4        Under 18s          Mixed (%)  Female          Count  People
# 67    3.4            Total          Mixed (%)  Female          Count  People
#
#     Age        Period
# 63  All  1 March 2017
# 64  All  1 March 2017
# 65  All  1 March 2017
# 66  All  1 March 2017
# 67  All  1 March 2017

# %%
new_table.count()
# Out:
# Value                 68
# Treatment Type        68
# Residential Status    68
# Sex                   68
# Measure Type          68
# Unit                  68
# Age                   68
# Period                68
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value                 66
# Treatment Type        66
# Residential Status    66
# Sex                   66
# Measure Type          66
# Unit                  66
# Age                   66
# Period                66
# dtype: int64

# %%
new_table['Service Type'] = 'all'
# new_table['Residential Status'] = 'All'
new_table['Health and Social Care Trust']  = 'all'
# Out:
# /Users/leigh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/leigh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_table = new_table[['Period', 'Sex', 'Age', 'Service Type', 'Residential Status', 'Treatment Type', 'Health and Social Care Trust', 'Measure Type', 'Unit', 'Value']]

# %%
new_table.head(5)
# Out:
#          Period   Sex  Age Service Type Residential Status   Treatment Type  \
# 0  1 March 2017  Male  All          all        Residential     Alcohol Only
# 1  1 March 2017  Male  All          all        Residential       Drugs Only
# 2  1 March 2017  Male  All          all        Residential  Drugs & Alcohol
# 4  1 March 2017  Male  All          all        Residential      18 and over
# 5  1 March 2017  Male  All          all        Residential            Total
#
#   Health and Social Care Trust Measure Type    Unit  Value
# 0                          all        Count  People  108.0
# 1                          all        Count  People   22.0
# 2                          all        Count  People  204.0
# 4                          all        Count  People  334.0
# 5                          all        Count  People  334.0

# %%
#new_table.to_csv('testCompare.csv', index = False)

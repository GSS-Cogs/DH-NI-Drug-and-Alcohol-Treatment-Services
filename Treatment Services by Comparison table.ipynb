# %% [markdown]
# Census of Drug and Alcohol Treatment Type Services in Northern Ireland:Table 5 Comparison table

# %%
from gssutils import *
import numpy
if is_interactive():
    import requests
    
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
    inputFile = sourceFolder / 'data-census-drug-alcohol-Treatment Type-services.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 5')[0]
# Out:
# Loading in/data-census-drug-alcohol-Treatment Type-services.xlsx which has size 46265 bytes
# Table names: ['Table 5']

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('J8').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<I9 37.1>, <F23 5775.0>, <D20 205.0>, <G12 93.3>, <F27 675.0>, <F29 1015.0>, <F12 5518.0>, <C31 2.5>, <G30 3.1>, <G22 2.4>, <D16 1224.0>, <F8 4066.0>, <B20 257.0>, <I27 18.5>, <H9 3176.0>, <B19 3585.0>, <H14 3891.0>, <G20 3.1>, <J6 5969.0>, <I16 23.9>, <I8 62.9>, <B30 257.0>, <F18 1905.0>, <B18 1741.0>, <B12 4736.0>, <G29 17.2>, <H30 313.0>, <E12 89.0>, <E22 2.3>, <C23 97.9>, <H31 129.0>, <B23 5467.0>, <H20 313.0>, <I20 3.7>, <G6 100.0>, <E26 23.1>, <E6 100.0>, <D18 1606.0>, <H16 2045.0>, <G28 21.0>, <G18 32.2>, <I29 15.0>, <I30 3.7>, <E11 11.0>, <B15 1118.0>, <B22 116.0>, <G8 68.7>, <D30 205.0>, <C12 84.8>, <E31 3.1>, <H18 3646.0>, <D25 1272.0>, <B11 847.0>, <D8 4244.0>, <F16 1291.0>, <C22 2.1>, <E9 27.4>, <C9 34.0>, <F15 1514.0>, <G11 6.7>, <E18 27.5>, <D15 1294.0>, <C18 31.2>, <B25 5185.0>, <G15 25.6>, <E14 56.9>, <I18 42.6>, <E20 3.5>, <F14 3111.0>, <G23 97.6>, <G16 21.8>, <E28 13.5>, <D6 5846.0>, <D9 1602.0>, <G25 26.0>, <H8 5377.0>, <F9 1850.0>, <C30 4.6>, <C14 62.3>, <D11 644.0>, <B14 3476.0>, <F11 398.0>, <F6 5916.0>, <H15 2617.0>, <B16 989.0>, <I26 10.4>, <D26 1349.0>, <E8 72.6>, <F26 1094.0>, <E23 97.7>, <C6 100.0>, <C19 64.2>, <I19 53.7>, <I31 1.5>, <F19 3827.0>, <G31 2.9>, <I14 45.5>, <C20 4.6>, <D31 182.0>, <D23 5713.0>, <H23 8101.0>, <H19 4594.0>, <C8 66.0>, <C25 92.9>, <H25 2425.0>, <E16 20.9>, <F22 141.0>, <G9 31.3>, <E19 69.0>, <I15 30.6>, <H28 1937.0>, <E29 13.6>, <E15 22.1>, <I12 89.9>, <I6 100.0>, <G27 11.4>, <H26 888.0>, <H6 8553.0>, <I22 5.3>, <D29 797.0>, <G19 64.7>, <F25 1536.0>, <C15 20.0>, <E25 21.8>, <B6 5583.0>, <I11 10.1>, <F31 172.0>, <D19 4035.0>, <H22 452.0>, <E27 21.4>, <H11 862.0>, <D28 789.0>, <F30 184.0>, <F28 1240.0>, <F20 184.0>, <K6 100.0>, <H29 1279.0>, <C11 15.2>, <B31 141.0>, <I28 22.6>, <H27 1582.0>, <D12 5202.0>, <C16 17.7>, <I25 28.4>, <G14 52.6>, <B8 3686.0>, <H12 7691.0>, <E30 3.5>, <G26 18.5>, <D22 133.0>, <B9 1897.0>, <D27 1252.0>, <D14 3328.0>, <I23 94.7>}

# %%
Service = tab.excel_ref('A').expand(DOWN).by_index([6,7,10,13,17,21,24])
Service
# Out:
# {<A6 'Total'>, <A10 'Age'>, <A13 'Treatment type'>, <A7 'Gender'>, <A24 'Trust'>, <A17 'Service type'>, <A21 'Residential Status'>}

# %%
TreatmentType = tab.excel_ref('A').expand(DOWN).is_not_blank() - tab.excel_ref('A').expand(DOWN).by_index([6,7,10,13,17,21,24])
TreatmentType
# Out:
# {<A8 'Male'>, <A11 'Under 18 '>, <A18 'Statutory'>, <A31 'Emergency admissions (HIS)'>, <A25 'Belfast'>, <A19 'Non-statutory'>, <A30 'Prison'>, <A20 'Prison'>, <A23 'Non-residential / Mixed'>, <A15 'Drugs Only'>, <A16 'Drugs & Alcohol'>, <A22 'Residential'>, <A27 'South Eastern'>, <A28 'Southern'>, <A1 'Table 5 – Comparison Table'>, <A26 'Northern'>, <A12 '18 and over'>, <A9 'Female  '>, <A14 'Alcohol Only'>, <A29 'Western'>}

# %%
month = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
month
# Out:
# {<F3 '1st March '>, <H3 '1st September'>, <D3 '1st March '>, <J3 '1st March '>, <B3 '1st March '>}

# %%
year = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
year
# Out:
# {<F4 2012.0>, <H4 2014.0>, <B4 2007.0>, <J4 2017.0>, <D4 2010.0>}

# %%
mt = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
mt
# Out:
# {<G5 '%'>, <B5 'Headcount'>, <I5 '%'>, <J5 'Headcount'>, <K5 '%'>, <D5 'Headcount'>, <F5 'Headcount'>, <C5 '%'>, <E5 '%'>, <H5 'Headcount'>}

# %%
Dimensions = [
            HDim(TreatmentType,'Treatment Type',DIRECTLY,LEFT),
            HDim(Service,'Category',CLOSEST,ABOVE),
            HDim(month,'month',CLOSEST,LEFT),
            HDim(year,'Year',CLOSEST,LEFT),
            HDim(mt,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People'),
            HDimConst('Age','All'),
            HDimConst('Sex','Persons')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#         OBS              Treatment Type Category          month    Year  \
# 0    5583.0                        None    Total     1st March   2007.0
# 1     100.0                        None    Total     1st March   2007.0
# 2    5846.0                        None    Total     1st March   2010.0
# 3     100.0                        None    Total     1st March   2010.0
# 4    5916.0                        None    Total     1st March   2012.0
# 5     100.0                        None    Total     1st March   2012.0
# 6    8553.0                        None    Total  1st September  2014.0
# 7     100.0                        None    Total  1st September  2014.0
# 8    5969.0                        None    Total     1st March   2017.0
# 9     100.0                        None    Total     1st March   2017.0
# 10   3686.0                        Male   Gender     1st March   2007.0
# 11     66.0                        Male   Gender     1st March   2007.0
# 12   4244.0                        Male   Gender     1st March   2010.0
# 13     72.6                        Male   Gender     1st March   2010.0
# 14   4066.0                        Male   Gender     1st March   2012.0
# 15     68.7                        Male   Gender     1st March   2012.0
# 16   5377.0                        Male   Gender  1st September  2014.0
# 17     62.9                        Male   Gender  1st September  2014.0
# 18   1897.0                    Female     Gender     1st March   2007.0
# 19     34.0                    Female     Gender     1st March   2007.0
# 20   1602.0                    Female     Gender     1st March   2010.0
# 21     27.4                    Female     Gender     1st March   2010.0
# 22   1850.0                    Female     Gender     1st March   2012.0
# 23     31.3                    Female     Gender     1st March   2012.0
# 24   3176.0                    Female     Gender  1st September  2014.0
# 25     37.1                    Female     Gender  1st September  2014.0
# 26    847.0                   Under 18       Age     1st March   2007.0
# 27     15.2                   Under 18       Age     1st March   2007.0
# 28    644.0                   Under 18       Age     1st March   2010.0
# 29     11.0                   Under 18       Age     1st March   2010.0
# ..      ...                         ...      ...            ...     ...
# 124  1582.0               South Eastern    Trust  1st September  2014.0
# 125    18.5               South Eastern    Trust  1st September  2014.0
# 126   789.0                    Southern    Trust     1st March   2010.0
# 127    13.5                    Southern    Trust     1st March   2010.0
# 128  1240.0                    Southern    Trust     1st March   2012.0
# 129    21.0                    Southern    Trust     1st March   2012.0
# 130  1937.0                    Southern    Trust  1st September  2014.0
# 131    22.6                    Southern    Trust  1st September  2014.0
# 132   797.0                     Western    Trust     1st March   2010.0
# 133    13.6                     Western    Trust     1st March   2010.0
# 134  1015.0                     Western    Trust     1st March   2012.0
# 135    17.2                     Western    Trust     1st March   2012.0
# 136  1279.0                     Western    Trust  1st September  2014.0
# 137    15.0                     Western    Trust  1st September  2014.0
# 138   257.0                      Prison    Trust     1st March   2007.0
# 139     4.6                      Prison    Trust     1st March   2007.0
# 140   205.0                      Prison    Trust     1st March   2010.0
# 141     3.5                      Prison    Trust     1st March   2010.0
# 142   184.0                      Prison    Trust     1st March   2012.0
# 143     3.1                      Prison    Trust     1st March   2012.0
# 144   313.0                      Prison    Trust  1st September  2014.0
# 145     3.7                      Prison    Trust  1st September  2014.0
# 146   141.0  Emergency admissions (HIS)    Trust     1st March   2007.0
# 147     2.5  Emergency admissions (HIS)    Trust     1st March   2007.0
# 148   182.0  Emergency admissions (HIS)    Trust     1st March   2010.0
# 149     3.1  Emergency admissions (HIS)    Trust     1st March   2010.0
# 150   172.0  Emergency admissions (HIS)    Trust     1st March   2012.0
# 151     2.9  Emergency admissions (HIS)    Trust     1st March   2012.0
# 152   129.0  Emergency admissions (HIS)    Trust  1st September  2014.0
# 153     1.5  Emergency admissions (HIS)    Trust  1st September  2014.0
#
#     Measure Type    Unit  Age      Sex
# 0      Headcount  People  All  Persons
# 1              %  People  All  Persons
# 2      Headcount  People  All  Persons
# 3              %  People  All  Persons
# 4      Headcount  People  All  Persons
# 5              %  People  All  Persons
# 6      Headcount  People  All  Persons
# 7              %  People  All  Persons
# 8      Headcount  People  All  Persons
# 9              %  People  All  Persons
# 10     Headcount  People  All  Persons
# 11             %  People  All  Persons
# 12     Headcount  People  All  Persons
# 13             %  People  All  Persons
# 14     Headcount  People  All  Persons
# 15             %  People  All  Persons
# 16     Headcount  People  All  Persons
# 17             %  People  All  Persons
# 18     Headcount  People  All  Persons
# 19             %  People  All  Persons
# 20     Headcount  People  All  Persons
# 21             %  People  All  Persons
# 22     Headcount  People  All  Persons
# 23             %  People  All  Persons
# 24     Headcount  People  All  Persons
# 25             %  People  All  Persons
# 26     Headcount  People  All  Persons
# 27             %  People  All  Persons
# 28     Headcount  People  All  Persons
# 29             %  People  All  Persons
# ..           ...     ...  ...      ...
# 124    Headcount  People  All  Persons
# 125            %  People  All  Persons
# 126    Headcount  People  All  Persons
# 127            %  People  All  Persons
# 128    Headcount  People  All  Persons
# 129            %  People  All  Persons
# 130    Headcount  People  All  Persons
# 131            %  People  All  Persons
# 132    Headcount  People  All  Persons
# 133            %  People  All  Persons
# 134    Headcount  People  All  Persons
# 135            %  People  All  Persons
# 136    Headcount  People  All  Persons
# 137            %  People  All  Persons
# 138    Headcount  People  All  Persons
# 139            %  People  All  Persons
# 140    Headcount  People  All  Persons
# 141            %  People  All  Persons
# 142    Headcount  People  All  Persons
# 143            %  People  All  Persons
# 144    Headcount  People  All  Persons
# 145            %  People  All  Persons
# 146    Headcount  People  All  Persons
# 147            %  People  All  Persons
# 148    Headcount  People  All  Persons
# 149            %  People  All  Persons
# 150    Headcount  People  All  Persons
# 151            %  People  All  Persons
# 152    Headcount  People  All  Persons
# 153            %  People  All  Persons
#
# [154 rows x 9 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Category           object
# month              object
# Year               object
# Measure Type       object
# Unit               object
# Age                object
# Sex                object
# dtype: object

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Category           object
# month              object
# Year               object
# Measure Type       object
# Unit               object
# Age                object
# Sex                object
# dtype: object

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table['Period'] = new_table['month'] + new_table['Year']

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        '%' : 'Percentage of Headcount'
        }.get(x, x))

# %%
new_table.tail(5)
# Out:
#      Value              Treatment Type Category          month  Year  \
# 149    3.1  Emergency admissions (HIS)    Trust     1st March   2010
# 150  172.0  Emergency admissions (HIS)    Trust     1st March   2012
# 151    2.9  Emergency admissions (HIS)    Trust     1st March   2012
# 152  129.0  Emergency admissions (HIS)    Trust  1st September  2014
# 153    1.5  Emergency admissions (HIS)    Trust  1st September  2014
#
#                 Measure Type    Unit  Age      Sex             Period
# 149  Percentage of Headcount  People  All  Persons     1st March 2010
# 150                Headcount  People  All  Persons     1st March 2012
# 151  Percentage of Headcount  People  All  Persons     1st March 2012
# 152                Headcount  People  All  Persons  1st September2014
# 153  Percentage of Headcount  People  All  Persons  1st September2014

# %%
new_table.count()
# Out:
# Value             154
# Treatment Type    144
# Category          154
# month             154
# Year              154
# Measure Type      154
# Unit              154
# Age               154
# Sex               154
# Period            154
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value             154
# Treatment Type    144
# Category          154
# month             154
# Year              154
# Measure Type      154
# Unit              154
# Age               154
# Sex               154
# Period            154
# dtype: int64

# %%
new_table['Treatment Type'].unique()
new_table['Treatment Type'] = new_table['Treatment Type'].str.strip() #Get rid of extra spce at end of Under 18

# %%
new_table['Treatment Type'].fillna('All', inplace = True)

# %%
new_table
# Out:
#       Value              Treatment Type Category          month  Year  \
# 0    5583.0                         All    Total     1st March   2007
# 1     100.0                         All    Total     1st March   2007
# 2    5846.0                         All    Total     1st March   2010
# 3     100.0                         All    Total     1st March   2010
# 4    5916.0                         All    Total     1st March   2012
# 5     100.0                         All    Total     1st March   2012
# 6    8553.0                         All    Total  1st September  2014
# 7     100.0                         All    Total  1st September  2014
# 8    5969.0                         All    Total     1st March   2017
# 9     100.0                         All    Total     1st March   2017
# 10   3686.0                        Male   Gender     1st March   2007
# 11     66.0                        Male   Gender     1st March   2007
# 12   4244.0                        Male   Gender     1st March   2010
# 13     72.6                        Male   Gender     1st March   2010
# 14   4066.0                        Male   Gender     1st March   2012
# 15     68.7                        Male   Gender     1st March   2012
# 16   5377.0                        Male   Gender  1st September  2014
# 17     62.9                        Male   Gender  1st September  2014
# 18   1897.0                      Female   Gender     1st March   2007
# 19     34.0                      Female   Gender     1st March   2007
# 20   1602.0                      Female   Gender     1st March   2010
# 21     27.4                      Female   Gender     1st March   2010
# 22   1850.0                      Female   Gender     1st March   2012
# 23     31.3                      Female   Gender     1st March   2012
# 24   3176.0                      Female   Gender  1st September  2014
# 25     37.1                      Female   Gender  1st September  2014
# 26    847.0                    Under 18      Age     1st March   2007
# 27     15.2                    Under 18      Age     1st March   2007
# 28    644.0                    Under 18      Age     1st March   2010
# 29     11.0                    Under 18      Age     1st March   2010
# ..      ...                         ...      ...            ...   ...
# 124  1582.0               South Eastern    Trust  1st September  2014
# 125    18.5               South Eastern    Trust  1st September  2014
# 126   789.0                    Southern    Trust     1st March   2010
# 127    13.5                    Southern    Trust     1st March   2010
# 128  1240.0                    Southern    Trust     1st March   2012
# 129    21.0                    Southern    Trust     1st March   2012
# 130  1937.0                    Southern    Trust  1st September  2014
# 131    22.6                    Southern    Trust  1st September  2014
# 132   797.0                     Western    Trust     1st March   2010
# 133    13.6                     Western    Trust     1st March   2010
# 134  1015.0                     Western    Trust     1st March   2012
# 135    17.2                     Western    Trust     1st March   2012
# 136  1279.0                     Western    Trust  1st September  2014
# 137    15.0                     Western    Trust  1st September  2014
# 138   257.0                      Prison    Trust     1st March   2007
# 139     4.6                      Prison    Trust     1st March   2007
# 140   205.0                      Prison    Trust     1st March   2010
# 141     3.5                      Prison    Trust     1st March   2010
# 142   184.0                      Prison    Trust     1st March   2012
# 143     3.1                      Prison    Trust     1st March   2012
# 144   313.0                      Prison    Trust  1st September  2014
# 145     3.7                      Prison    Trust  1st September  2014
# 146   141.0  Emergency admissions (HIS)    Trust     1st March   2007
# 147     2.5  Emergency admissions (HIS)    Trust     1st March   2007
# 148   182.0  Emergency admissions (HIS)    Trust     1st March   2010
# 149     3.1  Emergency admissions (HIS)    Trust     1st March   2010
# 150   172.0  Emergency admissions (HIS)    Trust     1st March   2012
# 151     2.9  Emergency admissions (HIS)    Trust     1st March   2012
# 152   129.0  Emergency admissions (HIS)    Trust  1st September  2014
# 153     1.5  Emergency admissions (HIS)    Trust  1st September  2014
#
#                 Measure Type    Unit  Age      Sex             Period
# 0                  Headcount  People  All  Persons     1st March 2007
# 1    Percentage of Headcount  People  All  Persons     1st March 2007
# 2                  Headcount  People  All  Persons     1st March 2010
# 3    Percentage of Headcount  People  All  Persons     1st March 2010
# 4                  Headcount  People  All  Persons     1st March 2012
# 5    Percentage of Headcount  People  All  Persons     1st March 2012
# 6                  Headcount  People  All  Persons  1st September2014
# 7    Percentage of Headcount  People  All  Persons  1st September2014
# 8                  Headcount  People  All  Persons     1st March 2017
# 9    Percentage of Headcount  People  All  Persons     1st March 2017
# 10                 Headcount  People  All  Persons     1st March 2007
# 11   Percentage of Headcount  People  All  Persons     1st March 2007
# 12                 Headcount  People  All  Persons     1st March 2010
# 13   Percentage of Headcount  People  All  Persons     1st March 2010
# 14                 Headcount  People  All  Persons     1st March 2012
# 15   Percentage of Headcount  People  All  Persons     1st March 2012
# 16                 Headcount  People  All  Persons  1st September2014
# 17   Percentage of Headcount  People  All  Persons  1st September2014
# 18                 Headcount  People  All  Persons     1st March 2007
# 19   Percentage of Headcount  People  All  Persons     1st March 2007
# 20                 Headcount  People  All  Persons     1st March 2010
# 21   Percentage of Headcount  People  All  Persons     1st March 2010
# 22                 Headcount  People  All  Persons     1st March 2012
# 23   Percentage of Headcount  People  All  Persons     1st March 2012
# 24                 Headcount  People  All  Persons  1st September2014
# 25   Percentage of Headcount  People  All  Persons  1st September2014
# 26                 Headcount  People  All  Persons     1st March 2007
# 27   Percentage of Headcount  People  All  Persons     1st March 2007
# 28                 Headcount  People  All  Persons     1st March 2010
# 29   Percentage of Headcount  People  All  Persons     1st March 2010
# ..                       ...     ...  ...      ...                ...
# 124                Headcount  People  All  Persons  1st September2014
# 125  Percentage of Headcount  People  All  Persons  1st September2014
# 126                Headcount  People  All  Persons     1st March 2010
# 127  Percentage of Headcount  People  All  Persons     1st March 2010
# 128                Headcount  People  All  Persons     1st March 2012
# 129  Percentage of Headcount  People  All  Persons     1st March 2012
# 130                Headcount  People  All  Persons  1st September2014
# 131  Percentage of Headcount  People  All  Persons  1st September2014
# 132                Headcount  People  All  Persons     1st March 2010
# 133  Percentage of Headcount  People  All  Persons     1st March 2010
# 134                Headcount  People  All  Persons     1st March 2012
# 135  Percentage of Headcount  People  All  Persons     1st March 2012
# 136                Headcount  People  All  Persons  1st September2014
# 137  Percentage of Headcount  People  All  Persons  1st September2014
# 138                Headcount  People  All  Persons     1st March 2007
# 139  Percentage of Headcount  People  All  Persons     1st March 2007
# 140                Headcount  People  All  Persons     1st March 2010
# 141  Percentage of Headcount  People  All  Persons     1st March 2010
# 142                Headcount  People  All  Persons     1st March 2012
# 143  Percentage of Headcount  People  All  Persons     1st March 2012
# 144                Headcount  People  All  Persons  1st September2014
# 145  Percentage of Headcount  People  All  Persons  1st September2014
# 146                Headcount  People  All  Persons     1st March 2007
# 147  Percentage of Headcount  People  All  Persons     1st March 2007
# 148                Headcount  People  All  Persons     1st March 2010
# 149  Percentage of Headcount  People  All  Persons     1st March 2010
# 150                Headcount  People  All  Persons     1st March 2012
# 151  Percentage of Headcount  People  All  Persons     1st March 2012
# 152                Headcount  People  All  Persons  1st September2014
# 153  Percentage of Headcount  People  All  Persons  1st September2014
#
# [154 rows x 10 columns]

# %%
new_table['Service Type'] = 'All'
new_table['Residential Status'] = 'All'
new_table['Health and Social Care Trust']  = 'All'

# Get everything in the right columns
new_table['Age'] = numpy.where(new_table['Category'] == 'Age', new_table['Treatment Type'], 'All')
new_table['Sex'] = numpy.where(new_table['Category'] == 'Gender', new_table['Treatment Type'], 'All')
new_table['Service type'] = numpy.where(new_table['Category'] == 'Service type', new_table['Treatment Type'], 'All')
new_table['Residential Status'] = numpy.where(new_table['Category'] == 'Residential Status', new_table['Treatment Type'], 'All')
new_table['Trust'] = numpy.where(new_table['Category'] == 'Trust', new_table['Treatment Type'], 'All')

new_table['Treatment Type'] = numpy.where(new_table['Category'] == 'Treatment type', new_table['Treatment Type'], 'All')

# Merged cell over 5 rows for 2007, equals total for a few trusts rather than just one. Need to change Trust
new_table['Trust'] = numpy.where((new_table['Category'] == 'Trust') & 
                (new_table['Period'] == '1st March 2007') &
                (new_table['Trust'] == 'Belfast'), 
                'Belfast + Northern + South Eastern + Southern + Western', new_table['Trust'])

#new_table.to_csv('testCompare.csv', index = False)
new_table
# Out:
#       Value Treatment Type Category          month  Year  \
# 0    5583.0            All    Total     1st March   2007
# 1     100.0            All    Total     1st March   2007
# 2    5846.0            All    Total     1st March   2010
# 3     100.0            All    Total     1st March   2010
# 4    5916.0            All    Total     1st March   2012
# 5     100.0            All    Total     1st March   2012
# 6    8553.0            All    Total  1st September  2014
# 7     100.0            All    Total  1st September  2014
# 8    5969.0            All    Total     1st March   2017
# 9     100.0            All    Total     1st March   2017
# 10   3686.0            All   Gender     1st March   2007
# 11     66.0            All   Gender     1st March   2007
# 12   4244.0            All   Gender     1st March   2010
# 13     72.6            All   Gender     1st March   2010
# 14   4066.0            All   Gender     1st March   2012
# 15     68.7            All   Gender     1st March   2012
# 16   5377.0            All   Gender  1st September  2014
# 17     62.9            All   Gender  1st September  2014
# 18   1897.0            All   Gender     1st March   2007
# 19     34.0            All   Gender     1st March   2007
# 20   1602.0            All   Gender     1st March   2010
# 21     27.4            All   Gender     1st March   2010
# 22   1850.0            All   Gender     1st March   2012
# 23     31.3            All   Gender     1st March   2012
# 24   3176.0            All   Gender  1st September  2014
# 25     37.1            All   Gender  1st September  2014
# 26    847.0            All      Age     1st March   2007
# 27     15.2            All      Age     1st March   2007
# 28    644.0            All      Age     1st March   2010
# 29     11.0            All      Age     1st March   2010
# ..      ...            ...      ...            ...   ...
# 124  1582.0            All    Trust  1st September  2014
# 125    18.5            All    Trust  1st September  2014
# 126   789.0            All    Trust     1st March   2010
# 127    13.5            All    Trust     1st March   2010
# 128  1240.0            All    Trust     1st March   2012
# 129    21.0            All    Trust     1st March   2012
# 130  1937.0            All    Trust  1st September  2014
# 131    22.6            All    Trust  1st September  2014
# 132   797.0            All    Trust     1st March   2010
# 133    13.6            All    Trust     1st March   2010
# 134  1015.0            All    Trust     1st March   2012
# 135    17.2            All    Trust     1st March   2012
# 136  1279.0            All    Trust  1st September  2014
# 137    15.0            All    Trust  1st September  2014
# 138   257.0            All    Trust     1st March   2007
# 139     4.6            All    Trust     1st March   2007
# 140   205.0            All    Trust     1st March   2010
# 141     3.5            All    Trust     1st March   2010
# 142   184.0            All    Trust     1st March   2012
# 143     3.1            All    Trust     1st March   2012
# 144   313.0            All    Trust  1st September  2014
# 145     3.7            All    Trust  1st September  2014
# 146   141.0            All    Trust     1st March   2007
# 147     2.5            All    Trust     1st March   2007
# 148   182.0            All    Trust     1st March   2010
# 149     3.1            All    Trust     1st March   2010
# 150   172.0            All    Trust     1st March   2012
# 151     2.9            All    Trust     1st March   2012
# 152   129.0            All    Trust  1st September  2014
# 153     1.5            All    Trust  1st September  2014
#
#                 Measure Type    Unit       Age     Sex             Period  \
# 0                  Headcount  People       All     All     1st March 2007
# 1    Percentage of Headcount  People       All     All     1st March 2007
# 2                  Headcount  People       All     All     1st March 2010
# 3    Percentage of Headcount  People       All     All     1st March 2010
# 4                  Headcount  People       All     All     1st March 2012
# 5    Percentage of Headcount  People       All     All     1st March 2012
# 6                  Headcount  People       All     All  1st September2014
# 7    Percentage of Headcount  People       All     All  1st September2014
# 8                  Headcount  People       All     All     1st March 2017
# 9    Percentage of Headcount  People       All     All     1st March 2017
# 10                 Headcount  People       All    Male     1st March 2007
# 11   Percentage of Headcount  People       All    Male     1st March 2007
# 12                 Headcount  People       All    Male     1st March 2010
# 13   Percentage of Headcount  People       All    Male     1st March 2010
# 14                 Headcount  People       All    Male     1st March 2012
# 15   Percentage of Headcount  People       All    Male     1st March 2012
# 16                 Headcount  People       All    Male  1st September2014
# 17   Percentage of Headcount  People       All    Male  1st September2014
# 18                 Headcount  People       All  Female     1st March 2007
# 19   Percentage of Headcount  People       All  Female     1st March 2007
# 20                 Headcount  People       All  Female     1st March 2010
# 21   Percentage of Headcount  People       All  Female     1st March 2010
# 22                 Headcount  People       All  Female     1st March 2012
# 23   Percentage of Headcount  People       All  Female     1st March 2012
# 24                 Headcount  People       All  Female  1st September2014
# 25   Percentage of Headcount  People       All  Female  1st September2014
# 26                 Headcount  People  Under 18     All     1st March 2007
# 27   Percentage of Headcount  People  Under 18     All     1st March 2007
# 28                 Headcount  People  Under 18     All     1st March 2010
# 29   Percentage of Headcount  People  Under 18     All     1st March 2010
# ..                       ...     ...       ...     ...                ...
# 124                Headcount  People       All     All  1st September2014
# 125  Percentage of Headcount  People       All     All  1st September2014
# 126                Headcount  People       All     All     1st March 2010
# 127  Percentage of Headcount  People       All     All     1st March 2010
# 128                Headcount  People       All     All     1st March 2012
# 129  Percentage of Headcount  People       All     All     1st March 2012
# 130                Headcount  People       All     All  1st September2014
# 131  Percentage of Headcount  People       All     All  1st September2014
# 132                Headcount  People       All     All     1st March 2010
# 133  Percentage of Headcount  People       All     All     1st March 2010
# 134                Headcount  People       All     All     1st March 2012
# 135  Percentage of Headcount  People       All     All     1st March 2012
# 136                Headcount  People       All     All  1st September2014
# 137  Percentage of Headcount  People       All     All  1st September2014
# 138                Headcount  People       All     All     1st March 2007
# 139  Percentage of Headcount  People       All     All     1st March 2007
# 140                Headcount  People       All     All     1st March 2010
# 141  Percentage of Headcount  People       All     All     1st March 2010
# 142                Headcount  People       All     All     1st March 2012
# 143  Percentage of Headcount  People       All     All     1st March 2012
# 144                Headcount  People       All     All  1st September2014
# 145  Percentage of Headcount  People       All     All  1st September2014
# 146                Headcount  People       All     All     1st March 2007
# 147  Percentage of Headcount  People       All     All     1st March 2007
# 148                Headcount  People       All     All     1st March 2010
# 149  Percentage of Headcount  People       All     All     1st March 2010
# 150                Headcount  People       All     All     1st March 2012
# 151  Percentage of Headcount  People       All     All     1st March 2012
# 152                Headcount  People       All     All  1st September2014
# 153  Percentage of Headcount  People       All     All  1st September2014
#
#     Service Type Residential Status Health and Social Care Trust Service type  \
# 0            All                All                          All          All
# 1            All                All                          All          All
# 2            All                All                          All          All
# 3            All                All                          All          All
# 4            All                All                          All          All
# 5            All                All                          All          All
# 6            All                All                          All          All
# 7            All                All                          All          All
# 8            All                All                          All          All
# 9            All                All                          All          All
# 10           All                All                          All          All
# 11           All                All                          All          All
# 12           All                All                          All          All
# 13           All                All                          All          All
# 14           All                All                          All          All
# 15           All                All                          All          All
# 16           All                All                          All          All
# 17           All                All                          All          All
# 18           All                All                          All          All
# 19           All                All                          All          All
# 20           All                All                          All          All
# 21           All                All                          All          All
# 22           All                All                          All          All
# 23           All                All                          All          All
# 24           All                All                          All          All
# 25           All                All                          All          All
# 26           All                All                          All          All
# 27           All                All                          All          All
# 28           All                All                          All          All
# 29           All                All                          All          All
# ..           ...                ...                          ...          ...
# 124          All                All                          All          All
# 125          All                All                          All          All
# 126          All                All                          All          All
# 127          All                All                          All          All
# 128          All                All                          All          All
# 129          All                All                          All          All
# 130          All                All                          All          All
# 131          All                All                          All          All
# 132          All                All                          All          All
# 133          All                All                          All          All
# 134          All                All                          All          All
# 135          All                All                          All          All
# 136          All                All                          All          All
# 137          All                All                          All          All
# 138          All                All                          All          All
# 139          All                All                          All          All
# 140          All                All                          All          All
# 141          All                All                          All          All
# 142          All                All                          All          All
# 143          All                All                          All          All
# 144          All                All                          All          All
# 145          All                All                          All          All
# 146          All                All                          All          All
# 147          All                All                          All          All
# 148          All                All                          All          All
# 149          All                All                          All          All
# 150          All                All                          All          All
# 151          All                All                          All          All
# 152          All                All                          All          All
# 153          All                All                          All          All
#
#                           Trust
# 0                           All
# 1                           All
# 2                           All
# 3                           All
# 4                           All
# 5                           All
# 6                           All
# 7                           All
# 8                           All
# 9                           All
# 10                          All
# 11                          All
# 12                          All
# 13                          All
# 14                          All
# 15                          All
# 16                          All
# 17                          All
# 18                          All
# 19                          All
# 20                          All
# 21                          All
# 22                          All
# 23                          All
# 24                          All
# 25                          All
# 26                          All
# 27                          All
# 28                          All
# 29                          All
# ..                          ...
# 124               South Eastern
# 125               South Eastern
# 126                    Southern
# 127                    Southern
# 128                    Southern
# 129                    Southern
# 130                    Southern
# 131                    Southern
# 132                     Western
# 133                     Western
# 134                     Western
# 135                     Western
# 136                     Western
# 137                     Western
# 138                      Prison
# 139                      Prison
# 140                      Prison
# 141                      Prison
# 142                      Prison
# 143                      Prison
# 144                      Prison
# 145                      Prison
# 146  Emergency admissions (HIS)
# 147  Emergency admissions (HIS)
# 148  Emergency admissions (HIS)
# 149  Emergency admissions (HIS)
# 150  Emergency admissions (HIS)
# 151  Emergency admissions (HIS)
# 152  Emergency admissions (HIS)
# 153  Emergency admissions (HIS)
#
# [154 rows x 15 columns]

# %%
new_table = new_table[['Period', 'Sex', 'Age', 'Service Type', 'Residential Status', 'Treatment Type', 'Health and Social Care Trust', 'Measure Type', 'Unit', 'Value']]

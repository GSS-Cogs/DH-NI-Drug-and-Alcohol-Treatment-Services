# %% [markdown]
# Census of Drug and Alcohol Treatment Type Services in Northern Ireland:Table 5 Comparison table

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
inputFile = sourceFolder / 'data-census-drug-alcohol-Treatment Type-services.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-Treatment Type-services.xlsx

# %%
tab = loadxlstabs(inputFile, sheetids='Table 5')[0]
# Out:
# Loading in\data-census-drug-alcohol-Treatment Type-services.xlsx which has size 46265 bytes
# Table names: ['Table 5']

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B32').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<D26 1349.0>, <D15 1294.0>, <B19 3585.0>, <K25 25.1>, <J6 5969.0>, <B30 257.0>, <I8 62.9>, <B31 141.0>, <I28 22.6>, <H27 1582.0>, <B12 4736.0>, <G29 17.2>, <E14 56.9>, <I18 42.6>, <H12 7691.0>, <G16 21.8>, <H20 313.0>, <G6 100.0>, <B9 1897.0>, <K23 93.0>, <D9 1602.0>, <J19 2186.0>, <D16 1224.0>, <H23 8101.0>, <K16 22.7>, <D20 205.0>, <H19 4594.0>, <C8 66.0>, <I29 15.0>, <F27 675.0>, <E11 11.0>, <F29 1015.0>, <B15 1118.0>, <J8 4095.0>, <E19 69.0>, <H28 1937.0>, <E29 13.6>, <H15 2617.0>, <C12 84.8>, <K27 14.1>, <E31 3.1>, <K11 11.9>, <G19 64.7>, <E23 97.7>, <K26 17.1>, <C15 20.0>, <E25 21.8>, <B6 5583.0>, <F31 172.0>, <I16 23.9>, <H22 452.0>, <F18 1905.0>, <B18 1741.0>, <F30 184.0>, <I14 45.5>, <F20 184.0>, <K6 100.0>, <I20 3.7>, <E26 23.1>, <B25 5185.0>, <G15 25.6>, <D12 5202.0>, <C16 17.7>, <I25 28.4>, <B8 3686.0>, <I30 3.7>, <D6 5846.0>, <F22 141.0>, <E16 20.9>, <J29 1208.0>, <C30 4.6>, <F9 1850.0>, <H8 5377.0>, <I15 30.6>, <I9 37.1>, <F23 5775.0>, <I6 100.0>, <B14 3476.0>, <H18 3646.0>, <D29 797.0>, <F12 5518.0>, <C31 2.5>, <F25 1536.0>, <I11 10.1>, <K31 2.6>, <D8 4244.0>, <C22 2.1>, <E9 27.4>, <B16 989.0>, <C9 34.0>, <I26 10.4>, <J11 713.0>, <F26 1094.0>, <I27 18.5>, <K29 20.2>, <C19 64.2>, <H14 3891.0>, <H29 1279.0>, <I19 53.7>, <I31 1.5>, <J18 3600.0>, <F19 3827.0>, <G31 2.9>, <J14 2577.0>, <K22 7.0>, <E12 89.0>, <G14 52.6>, <H31 129.0>, <F14 3111.0>, <K18 60.3>, <D31 182.0>, <J16 1356.0>, <E28 13.5>, <J30 183.0>, <J9 1874.0>, <D18 1606.0>, <H16 2045.0>, <J27 841.0>, <C25 92.9>, <H25 2425.0>, <G9 31.3>, <D30 205.0>, <G30 3.1>, <H6 8553.0>, <J25 1498.0>, <C6 100.0>, <E8 72.6>, <B20 257.0>, <H9 3176.0>, <K20 3.1>, <D25 1272.0>, <K14 43.2>, <G20 3.1>, <K30 3.1>, <F15 1514.0>, <G11 6.7>, <H30 313.0>, <E18 27.5>, <E22 2.3>, <C23 97.9>, <C20 4.6>, <B23 5467.0>, <C11 15.2>, <E6 100.0>, <D23 5713.0>, <J22 417.0>, <G28 21.0>, <G18 32.2>, <J26 1023.0>, <E30 3.5>, <G23 97.6>, <G26 18.5>, <K12 88.1>, <D22 133.0>, <D27 1252.0>, <B22 116.0>, <J15 2036.0>, <D14 3328.0>, <C18 31.2>, <I23 94.7>, <E20 3.5>, <F8 4066.0>, <G8 68.7>, <G25 26.0>, <H11 862.0>, <J20 183.0>, <D11 644.0>, <C14 62.3>, <E15 22.1>, <I12 89.9>, <G12 93.3>, <G27 11.4>, <H26 888.0>, <J23 5552.0>, <I22 5.3>, <K15 34.1>, <K28 17.7>, <F11 398.0>, <F6 5916.0>, <K19 36.6>, <J12 5256.0>, <B11 847.0>, <K9 31.4>, <G22 2.4>, <D19 4035.0>, <F16 1291.0>, <E27 21.4>, <J28 1058.0>, <D28 789.0>, <K8 68.6>, <J31 158.0>, <F28 1240.0>}

# %%
Service = tab.excel_ref('A').expand(DOWN).by_index([6,7,10,13,17,21,24])
Service
# Out:
# {<A13 'Treatment type'>, <A21 'Residential Status'>, <A7 'Gender'>, <A10 'Age'>, <A17 'Service type'>, <A6 'Total'>, <A24 'Trust'>}

# %%
TreatmentType = tab.excel_ref('A').expand(DOWN).is_not_blank() - tab.excel_ref('A').expand(DOWN).by_index([6,7,10,13,17,21,24])
TreatmentType
# Out:
# {<A19 'Non-statutory'>, <A23 'Non-residential / Mixed'>, <A26 'Northern'>, <A1 'Table 5 – Comparison Table'>, <A22 'Residential'>, <A18 'Statutory'>, <A30 'Prison'>, <A25 'Belfast'>, <A12 '18 and over'>, <A16 'Drugs & Alcohol'>, <A28 'Southern'>, <A20 'Prison'>, <A11 'Under 18 '>, <A31 'Emergency admissions (HIS)'>, <A14 'Alcohol Only'>, <A8 'Male'>, <A9 'Female  '>, <A15 'Drugs Only'>, <A27 'South Eastern'>, <A29 'Western'>}

# %%
month = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
month
# Out:
# {<F3 '1st March '>, <J3 '1st March '>, <D3 '1st March '>, <B3 '1st March '>, <H3 '1st September'>}

# %%
year = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
year
# Out:
# {<F4 2012.0>, <D4 2010.0>, <B4 2007.0>, <H4 2014.0>, <J4 2017.0>}

# %%
mt = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
mt
# Out:
# {<G5 '%'>, <C5 '%'>, <I5 '%'>, <H5 'Headcount'>, <K5 '%'>, <F5 'Headcount'>, <J5 'Headcount'>, <D5 'Headcount'>, <E5 '%'>, <B5 'Headcount'>}

# %%
Dimensions = [
            HDim(TreatmentType,'Treatment Type',DIRECTLY,LEFT),
            HDim(Service,'Category',CLOSEST,ABOVE),
            HDim(month,'month',CLOSEST,LEFT),
            HDim(year,'Year',CLOSEST,LEFT),
            HDim(mt,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People'),
            HDimConst('Age','All'),
            HDimConst('Sex','Persons')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#         OBS              Treatment Type Category          month    Year  \
# 0    5583.0                        None    Total     1st March   2007.0
# 1     100.0                        None    Total     1st March   2007.0
# 2    5846.0                        None    Total     1st March   2010.0
# 3     100.0                        None    Total     1st March   2010.0
# 4    5916.0                        None    Total     1st March   2012.0
# 5     100.0                        None    Total     1st March   2012.0
# 6    8553.0                        None    Total  1st September  2014.0
# 7     100.0                        None    Total  1st September  2014.0
# 8    5969.0                        None    Total     1st March   2017.0
# 9     100.0                        None    Total     1st March   2017.0
# 10   3686.0                        Male   Gender     1st March   2007.0
# 11     66.0                        Male   Gender     1st March   2007.0
# 12   4244.0                        Male   Gender     1st March   2010.0
# 13     72.6                        Male   Gender     1st March   2010.0
# 14   4066.0                        Male   Gender     1st March   2012.0
# 15     68.7                        Male   Gender     1st March   2012.0
# 16   5377.0                        Male   Gender  1st September  2014.0
# 17     62.9                        Male   Gender  1st September  2014.0
# 18   4095.0                        Male   Gender     1st March   2017.0
# 19     68.6                        Male   Gender     1st March   2017.0
# 20   1897.0                    Female     Gender     1st March   2007.0
# 21     34.0                    Female     Gender     1st March   2007.0
# 22   1602.0                    Female     Gender     1st March   2010.0
# 23     27.4                    Female     Gender     1st March   2010.0
# 24   1850.0                    Female     Gender     1st March   2012.0
# 25     31.3                    Female     Gender     1st March   2012.0
# 26   3176.0                    Female     Gender  1st September  2014.0
# 27     37.1                    Female     Gender  1st September  2014.0
# 28   1874.0                    Female     Gender     1st March   2017.0
# 29     31.4                    Female     Gender     1st March   2017.0
# ..      ...                         ...      ...            ...     ...
# 162  1058.0                    Southern    Trust     1st March   2017.0
# 163    17.7                    Southern    Trust     1st March   2017.0
# 164   797.0                     Western    Trust     1st March   2010.0
# 165    13.6                     Western    Trust     1st March   2010.0
# 166  1015.0                     Western    Trust     1st March   2012.0
# 167    17.2                     Western    Trust     1st March   2012.0
# 168  1279.0                     Western    Trust  1st September  2014.0
# 169    15.0                     Western    Trust  1st September  2014.0
# 170  1208.0                     Western    Trust     1st March   2017.0
# 171    20.2                     Western    Trust     1st March   2017.0
# 172   257.0                      Prison    Trust     1st March   2007.0
# 173     4.6                      Prison    Trust     1st March   2007.0
# 174   205.0                      Prison    Trust     1st March   2010.0
# 175     3.5                      Prison    Trust     1st March   2010.0
# 176   184.0                      Prison    Trust     1st March   2012.0
# 177     3.1                      Prison    Trust     1st March   2012.0
# 178   313.0                      Prison    Trust  1st September  2014.0
# 179     3.7                      Prison    Trust  1st September  2014.0
# 180   183.0                      Prison    Trust     1st March   2017.0
# 181     3.1                      Prison    Trust     1st March   2017.0
# 182   141.0  Emergency admissions (HIS)    Trust     1st March   2007.0
# 183     2.5  Emergency admissions (HIS)    Trust     1st March   2007.0
# 184   182.0  Emergency admissions (HIS)    Trust     1st March   2010.0
# 185     3.1  Emergency admissions (HIS)    Trust     1st March   2010.0
# 186   172.0  Emergency admissions (HIS)    Trust     1st March   2012.0
# 187     2.9  Emergency admissions (HIS)    Trust     1st March   2012.0
# 188   129.0  Emergency admissions (HIS)    Trust  1st September  2014.0
# 189     1.5  Emergency admissions (HIS)    Trust  1st September  2014.0
# 190   158.0  Emergency admissions (HIS)    Trust     1st March   2017.0
# 191     2.6  Emergency admissions (HIS)    Trust     1st March   2017.0
#
#     Measure Type    Unit  Age      Sex
# 0      Headcount  People  All  Persons
# 1              %  People  All  Persons
# 2      Headcount  People  All  Persons
# 3              %  People  All  Persons
# 4      Headcount  People  All  Persons
# 5              %  People  All  Persons
# 6      Headcount  People  All  Persons
# 7              %  People  All  Persons
# 8      Headcount  People  All  Persons
# 9              %  People  All  Persons
# 10     Headcount  People  All  Persons
# 11             %  People  All  Persons
# 12     Headcount  People  All  Persons
# 13             %  People  All  Persons
# 14     Headcount  People  All  Persons
# 15             %  People  All  Persons
# 16     Headcount  People  All  Persons
# 17             %  People  All  Persons
# 18     Headcount  People  All  Persons
# 19             %  People  All  Persons
# 20     Headcount  People  All  Persons
# 21             %  People  All  Persons
# 22     Headcount  People  All  Persons
# 23             %  People  All  Persons
# 24     Headcount  People  All  Persons
# 25             %  People  All  Persons
# 26     Headcount  People  All  Persons
# 27             %  People  All  Persons
# 28     Headcount  People  All  Persons
# 29             %  People  All  Persons
# ..           ...     ...  ...      ...
# 162    Headcount  People  All  Persons
# 163            %  People  All  Persons
# 164    Headcount  People  All  Persons
# 165            %  People  All  Persons
# 166    Headcount  People  All  Persons
# 167            %  People  All  Persons
# 168    Headcount  People  All  Persons
# 169            %  People  All  Persons
# 170    Headcount  People  All  Persons
# 171            %  People  All  Persons
# 172    Headcount  People  All  Persons
# 173            %  People  All  Persons
# 174    Headcount  People  All  Persons
# 175            %  People  All  Persons
# 176    Headcount  People  All  Persons
# 177            %  People  All  Persons
# 178    Headcount  People  All  Persons
# 179            %  People  All  Persons
# 180    Headcount  People  All  Persons
# 181            %  People  All  Persons
# 182    Headcount  People  All  Persons
# 183            %  People  All  Persons
# 184    Headcount  People  All  Persons
# 185            %  People  All  Persons
# 186    Headcount  People  All  Persons
# 187            %  People  All  Persons
# 188    Headcount  People  All  Persons
# 189            %  People  All  Persons
# 190    Headcount  People  All  Persons
# 191            %  People  All  Persons
#
# [192 rows x 9 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Category           object
# month              object
# Year               object
# Measure Type       object
# Unit               object
# Age                object
# Sex                object
# dtype: object

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table['Period'] = new_table['month'] + new_table['Year']

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        '%' : 'Percentage of Headcount'
        }.get(x, x))

# %%
new_table.tail(5)
# Out:
#      Value              Treatment Type Category          month  Year  \
# 187    2.9  Emergency admissions (HIS)    Trust     1st March   2012
# 188  129.0  Emergency admissions (HIS)    Trust  1st September  2014
# 189    1.5  Emergency admissions (HIS)    Trust  1st September  2014
# 190  158.0  Emergency admissions (HIS)    Trust     1st March   2017
# 191    2.6  Emergency admissions (HIS)    Trust     1st March   2017
#
#                 Measure Type    Unit  Age      Sex             Period
# 187  Percentage of Headcount  People  All  Persons     1st March 2012
# 188                Headcount  People  All  Persons  1st September2014
# 189  Percentage of Headcount  People  All  Persons  1st September2014
# 190                Headcount  People  All  Persons     1st March 2017
# 191  Percentage of Headcount  People  All  Persons     1st March 2017

# %%
new_table.count()
# Out:
# Value             192
# Treatment Type    182
# Category          192
# month             192
# Year              192
# Measure Type      192
# Unit              192
# Age               192
# Sex               192
# Period            192
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value             192
# Treatment Type    182
# Category          192
# month             192
# Year              192
# Measure Type      192
# Unit              192
# Age               192
# Sex               192
# Period            192
# dtype: int64

# %%
new_table['Treatment Type'].unique()
# Out:
# array([None, 'Male', 'Female  ', 'Under 18 ', '18 and over',
#        'Alcohol Only', 'Drugs Only', 'Drugs & Alcohol', 'Statutory',
#        'Non-statutory', 'Prison', 'Residential', 'Non-residential / Mixed',
#        'Belfast', 'Northern', 'South Eastern', 'Southern', 'Western',
#        'Emergency admissions (HIS)'], dtype=object)

# %%
new_table['Treatment Type'].fillna('All', inplace = True)

# %%
new_table = new_table[['Period','Category','Age','Sex','Treatment Type','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#            Period Category  Age      Sex Treatment Type  \
# 0  1st March 2007    Total  All  Persons            All
# 1  1st March 2007    Total  All  Persons            All
# 2  1st March 2010    Total  All  Persons            All
# 3  1st March 2010    Total  All  Persons            All
# 4  1st March 2012    Total  All  Persons            All
#
#               Measure Type   Value    Unit
# 0                Headcount  5583.0  People
# 1  Percentage of Headcount   100.0  People
# 2                Headcount  5846.0  People
# 3  Percentage of Headcount   100.0  People
# 4                Headcount  5916.0  People

# %%
# destinationFolder = Path('out')
# destinationFolder.mkdir(exist_ok=True, parents=True)

# new_table.to_csv(destinationFolder / ('tab5.csv'), index = False)

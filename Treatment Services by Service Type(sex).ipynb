# %% [markdown]
# Census of Drug and Alcohol Treatment Services in Northern Ireland:Breakdown by Service Type

# %%
from gssutils import *
if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
    inputFile = sourceFolder / 'data-census-drug-alcohol-treatment-services.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 2')[0]
# Out:
# Loading in/data-census-drug-alcohol-treatment-services.xlsx which has size 46265 bytes
# Table names: ['Table 2']

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B12').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<E9 18.2>, <C9 61.8>, <K6 35.0>, <B8 5.0>, <G8 172.0>, <L6 1143.0>, <K9 18.9>, <M6 1178.0>, <D7 437.0>, <C6 925.0>, <K10 80.0>, <M11 0.6>, <K7 148.0>, <L7 537.0>, <H9 64.4>, <C7 571.0>, <C11 0.0>, <J6 141.0>, <H10 35.6>, <D9 41.5>, <E8 0.0>, <F8 172.0>, <F10 30.0>, <B7 493.0>, <L10 31.8>, <I11 0.0>, <I9 71.7>, <J9 43.5>, <G11 4.2>, <B11 0.3>, <D10 42.3>, <G7 1501.0>, <F11 4.8>, <I8 0.0>, <J10 53.1>, <G9 59.1>, <I7 153.0>, <E11 0.0>, <D8 167.0>, <E7 432.0>, <M8 11.0>, <J11 3.4>, <L9 67.7>, <J8 11.0>, <B10 31.5>, <M9 62.9>, <E10 81.8>, <F7 1069.0>, <E6 96.0>, <M7 685.0>, <H8 0.0>, <B6 1069.0>, <K8 11.0>, <C8 0.0>, <I10 28.3>, <J7 172.0>, <H11 0.0>, <D11 16.2>, <H7 360.0>, <C10 38.2>, <M10 36.6>, <B9 68.2>, <F6 2326.0>, <G6 2422.0>, <I6 387.0>, <K11 0.6>, <G10 36.7>, <H6 650.0>, <D6 428.0>, <F9 65.2>}

# %%
Service = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Service
# Out:
# {<A9 'Statutory (%)'>, <A7 'Non-statutory'>, <A5 'Total'>, <A19 'Statutory (%)'>, <A21 'Prison (%)'>, <A18 'Prison'>, <A20 'Non-statutory (%)'>, <A10 'Non-statutory (%)'>, <A17 'Non-statutory'>, <A8 'Prison'>, <A15 'Total'>, <A11 'Prison (%)'>, <A13 'Service Type'>, <A6 'Statutory'>, <A16 'Statutory'>}

# %%
Treatment = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Treatment
# Out:
# {<D4 'Drugs & Alcohol'>, <B4 'Alcohol Only'>, <E4 'Under 18s'>, <G4 'Total'>, <I4 'Drugs Only'>, <C4 'Drugs Only'>, <K4 'Under 18s'>, <J4 'Drugs & Alcohol'>, <F4 '18 and over'>, <M4 'Total'>, <H4 'Alcohol Only'>, <L4 '18 and over'>}

# %%
sex = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
sex
# Out:
# {<B3 'Male'>, <H3 'Female  '>}

# %%
Dimensions = [
            HDim(Treatment,'Treatment Type',DIRECTLY,ABOVE),
            HDim(Service,'Service Type',DIRECTLY,LEFT),
            HDim(sex,'Sex',CLOSEST,LEFT),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Period','1 March 2017'),
            HDimConst('Age','All')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS   Treatment Type       Service Type       Sex Measure Type    Unit  \
# 0   1069.0     Alcohol Only          Statutory      Male        Count  People
# 1    925.0       Drugs Only          Statutory      Male        Count  People
# 2    428.0  Drugs & Alcohol          Statutory      Male        Count  People
# 3     96.0        Under 18s          Statutory      Male        Count  People
# 4   2326.0      18 and over          Statutory      Male        Count  People
# 5   2422.0            Total          Statutory      Male        Count  People
# 6    650.0     Alcohol Only          Statutory  Female          Count  People
# 7    387.0       Drugs Only          Statutory  Female          Count  People
# 8    141.0  Drugs & Alcohol          Statutory  Female          Count  People
# 9     35.0        Under 18s          Statutory  Female          Count  People
# 10  1143.0      18 and over          Statutory  Female          Count  People
# 11  1178.0            Total          Statutory  Female          Count  People
# 12   493.0     Alcohol Only      Non-statutory      Male        Count  People
# 13   571.0       Drugs Only      Non-statutory      Male        Count  People
# 14   437.0  Drugs & Alcohol      Non-statutory      Male        Count  People
# 15   432.0        Under 18s      Non-statutory      Male        Count  People
# 16  1069.0      18 and over      Non-statutory      Male        Count  People
# 17  1501.0            Total      Non-statutory      Male        Count  People
# 18   360.0     Alcohol Only      Non-statutory  Female          Count  People
# 19   153.0       Drugs Only      Non-statutory  Female          Count  People
# 20   172.0  Drugs & Alcohol      Non-statutory  Female          Count  People
# 21   148.0        Under 18s      Non-statutory  Female          Count  People
# 22   537.0      18 and over      Non-statutory  Female          Count  People
# 23   685.0            Total      Non-statutory  Female          Count  People
# 24     5.0     Alcohol Only             Prison      Male        Count  People
# 25     0.0       Drugs Only             Prison      Male        Count  People
# 26   167.0  Drugs & Alcohol             Prison      Male        Count  People
# 27     0.0        Under 18s             Prison      Male        Count  People
# 28   172.0      18 and over             Prison      Male        Count  People
# 29   172.0            Total             Prison      Male        Count  People
# ..     ...              ...                ...       ...          ...     ...
# 40    59.1            Total      Statutory (%)      Male        Count  People
# 41    64.4     Alcohol Only      Statutory (%)  Female          Count  People
# 42    71.7       Drugs Only      Statutory (%)  Female          Count  People
# 43    43.5  Drugs & Alcohol      Statutory (%)  Female          Count  People
# 44    18.9        Under 18s      Statutory (%)  Female          Count  People
# 45    67.7      18 and over      Statutory (%)  Female          Count  People
# 46    62.9            Total      Statutory (%)  Female          Count  People
# 47    31.5     Alcohol Only  Non-statutory (%)      Male        Count  People
# 48    38.2       Drugs Only  Non-statutory (%)      Male        Count  People
# 49    42.3  Drugs & Alcohol  Non-statutory (%)      Male        Count  People
# 50    81.8        Under 18s  Non-statutory (%)      Male        Count  People
# 51    30.0      18 and over  Non-statutory (%)      Male        Count  People
# 52    36.7            Total  Non-statutory (%)      Male        Count  People
# 53    35.6     Alcohol Only  Non-statutory (%)  Female          Count  People
# 54    28.3       Drugs Only  Non-statutory (%)  Female          Count  People
# 55    53.1  Drugs & Alcohol  Non-statutory (%)  Female          Count  People
# 56    80.0        Under 18s  Non-statutory (%)  Female          Count  People
# 57    31.8      18 and over  Non-statutory (%)  Female          Count  People
# 58    36.6            Total  Non-statutory (%)  Female          Count  People
# 59     0.3     Alcohol Only         Prison (%)      Male        Count  People
# 60     0.0       Drugs Only         Prison (%)      Male        Count  People
# 61    16.2  Drugs & Alcohol         Prison (%)      Male        Count  People
# 62     0.0        Under 18s         Prison (%)      Male        Count  People
# 63     4.8      18 and over         Prison (%)      Male        Count  People
# 64     4.2            Total         Prison (%)      Male        Count  People
# 65     0.0     Alcohol Only         Prison (%)  Female          Count  People
# 66     0.0       Drugs Only         Prison (%)  Female          Count  People
# 67     3.4  Drugs & Alcohol         Prison (%)  Female          Count  People
# 68     0.6        Under 18s         Prison (%)  Female          Count  People
# 69     0.6            Total         Prison (%)  Female          Count  People
#
#           Period  Age
# 0   1 March 2017  All
# 1   1 March 2017  All
# 2   1 March 2017  All
# 3   1 March 2017  All
# 4   1 March 2017  All
# 5   1 March 2017  All
# 6   1 March 2017  All
# 7   1 March 2017  All
# 8   1 March 2017  All
# 9   1 March 2017  All
# 10  1 March 2017  All
# 11  1 March 2017  All
# 12  1 March 2017  All
# 13  1 March 2017  All
# 14  1 March 2017  All
# 15  1 March 2017  All
# 16  1 March 2017  All
# 17  1 March 2017  All
# 18  1 March 2017  All
# 19  1 March 2017  All
# 20  1 March 2017  All
# 21  1 March 2017  All
# 22  1 March 2017  All
# 23  1 March 2017  All
# 24  1 March 2017  All
# 25  1 March 2017  All
# 26  1 March 2017  All
# 27  1 March 2017  All
# 28  1 March 2017  All
# 29  1 March 2017  All
# ..           ...  ...
# 40  1 March 2017  All
# 41  1 March 2017  All
# 42  1 March 2017  All
# 43  1 March 2017  All
# 44  1 March 2017  All
# 45  1 March 2017  All
# 46  1 March 2017  All
# 47  1 March 2017  All
# 48  1 March 2017  All
# 49  1 March 2017  All
# 50  1 March 2017  All
# 51  1 March 2017  All
# 52  1 March 2017  All
# 53  1 March 2017  All
# 54  1 March 2017  All
# 55  1 March 2017  All
# 56  1 March 2017  All
# 57  1 March 2017  All
# 58  1 March 2017  All
# 59  1 March 2017  All
# 60  1 March 2017  All
# 61  1 March 2017  All
# 62  1 March 2017  All
# 63  1 March 2017  All
# 64  1 March 2017  All
# 65  1 March 2017  All
# 66  1 March 2017  All
# 67  1 March 2017  All
# 68  1 March 2017  All
# 69  1 March 2017  All
#
# [70 rows x 8 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Service Type       object
# Sex                object
# Measure Type       object
# Unit               object
# Period             object
# Age                object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value   Treatment Type Service Type       Sex Measure Type    Unit  \
# 65    0.0     Alcohol Only   Prison (%)  Female          Count  People
# 66    0.0       Drugs Only   Prison (%)  Female          Count  People
# 67    3.4  Drugs & Alcohol   Prison (%)  Female          Count  People
# 68    0.6        Under 18s   Prison (%)  Female          Count  People
# 69    0.6            Total   Prison (%)  Female          Count  People
#
#           Period  Age
# 65  1 March 2017  All
# 66  1 March 2017  All
# 67  1 March 2017  All
# 68  1 March 2017  All
# 69  1 March 2017  All

# %%
new_table.count()
# Out:
# Value             70
# Treatment Type    70
# Service Type      70
# Sex               70
# Measure Type      70
# Unit              70
# Period            70
# Age               70
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value             62
# Treatment Type    62
# Service Type      62
# Sex               62
# Measure Type      62
# Unit              62
# Period            62
# Age               62
# dtype: int64

# %%
new_table['Treatment Type'].fillna('All', inplace = True)
#new_table['Service Type'] = 'All'
new_table['Residential Status'] = 'All'
new_table['Health and Social Care Trust']  = 'All'
new_table['Service Type'].unique()
# Out:
# /Users/leigh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/leigh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 3         Under 18s                          All        Count  People    96.0
# 4       18 and over                          All        Count  People  2326.0
# 5             Total                          All        Count  People  2422.0
# 6      Alcohol Only                          All        Count  People   650.0
# 7        Drugs Only                          All        Count  People   387.0
# 8   Drugs & Alcohol                          All        Count  People   141.0
# 9         Under 18s                          All        Count  People    35.0
# 10      18 and over                          All        Count  People  1143.0
# 11            Total                          All        Count  People  1178.0
# 12     Alcohol Only                          All        Count  People   493.0
# 13       Drugs Only                          All        Count  People   571.0
# 14  Drugs & Alcohol                          All        Count  People   437.0
# 15        Under 18s                          All        Count  People   432.0
# 16      18 and over                          All        Count  People  1069.0
# 17            Total                          All        Count  People  1501.0
# 18     Alcohol Only                          All        Count  People   360.0
# 19       Drugs Only                          All        Count  People   153.0
# 20  Drugs & Alcohol                          All        Count  People   172.0
# 21        Under 18s                          All        Count  People   148.0
# 22      18 and over                          All        Count  People   537.0
# 23            Total                          All        Count  People   685.0
# 24     Alcohol Only                          All        Count  People     5.0
# 26  Drugs & Alcohol                          All        Count  People   167.0
# 28      18 and over                          All        Count  People   172.0
# 29            Total                          All        Count  People   172.0
# 32  Drugs & Alcohol                          All        Count  People    11.0
# 33        Under 18s                          All        Count  People    11.0
# ..              ...                          ...          ...     ...     ...
# 36       Drugs Only                          All        Count  People    61.8
# 37  Drugs & Alcohol                          All        Count  People    41.5
# 38        Under 18s                          All        Count  People    18.2
# 39      18 and over                          All        Count  People    65.2
# 40            Total                          All        Count  People    59.1
# 41     Alcohol Only                          All        Count  People    64.4
# 42       Drugs Only                          All        Count  People    71.7
# 43  Drugs & Alcohol                          All        Count  People    43.5
# 44        Under 18s                          All        Count  People    18.9
# 45      18 and over                          All        Count  People    67.7
# 46            Total                          All        Count  People    62.9
# 47     Alcohol Only                          All        Count  People    31.5
# 48       Drugs Only                          All        Count  People    38.2
# 49  Drugs & Alcohol                          All        Count  People    42.3
# 50        Under 18s                          All        Count  People    81.8
# 51      18 and over                          All        Count  People    30.0
# 52            Total                          All        Count  People    36.7
# 53     Alcohol Only                          All        Count  People    35.6
# 54       Drugs Only                          All        Count  People    28.3
# 55  Drugs & Alcohol                          All        Count  People    53.1
# 56        Under 18s                          All        Count  People    80.0
# 57      18 and over                          All        Count  People    31.8
# 58            Total                          All        Count  People    36.6
# 59     Alcohol Only                          All        Count  People     0.3
# 61  Drugs & Alcohol                          All        Count  People    16.2
# 63      18 and over                          All        Count  People     4.8
# 64            Total                          All        Count  People     4.2
# 67  Drugs & Alcohol                          All        Count  People     3.4
# 68        Under 18s                          All        Count  People     0.6
# 69            Total                          All        Count  People     0.6
#
# [62 rows x 10 columns]

# %%
new_table.tail()
# Out:
#           Period       Sex  Age Service Type Residential Status  \
# 63  1 March 2017      Male  All   Prison (%)                All
# 64  1 March 2017      Male  All   Prison (%)                All
# 67  1 March 2017  Female    All   Prison (%)                All
# 68  1 March 2017  Female    All   Prison (%)                All
# 69  1 March 2017  Female    All   Prison (%)                All
#
#      Treatment Type Health and Social Care Trust Measure Type    Unit  Value
# 63      18 and over                          All        Count  People    4.8
# 64            Total                          All        Count  People    4.2
# 67  Drugs & Alcohol                          All        Count  People    3.4
# 68        Under 18s                          All        Count  People    0.6
# 69            Total                          All        Count  People    0.6

# %%
new_table.to_csv('testCompare.csv', index = False)

# %% [markdown]
# Census of Drug and Alcohol Treatment Services in Northern Ireland:Breakdown by Service Type

# %%
from gssutils import *
if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.health-ni.gov.uk/sites/default/files/publications/dhssps/data-census-drug-alcohol-treatment-services.xlsx'
    inputFile = sourceFolder / 'data-census-drug-alcohol-treatment-services.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 2')[0]
# Out:
# Loading in\data-census-drug-alcohol-treatment-services.xlsx which has size 46265 bytes
# Table names: ['Table 2']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B12').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<E9 18.2>, <C9 61.8>, <K6 35.0>, <B8 5.0>, <H5 1010.0>, <G8 172.0>, <B5 1567.0>, <L6 1143.0>, <K9 18.9>, <M6 1178.0>, <D7 437.0>, <C6 925.0>, <K7 148.0>, <M11 0.6>, <L7 537.0>, <K10 80.0>, <H9 64.4>, <C7 571.0>, <C11 0.0>, <J6 141.0>, <I5 540.0>, <E5 528.0>, <L5 1689.0>, <H10 35.6>, <B7 493.0>, <C5 1496.0>, <J9 43.5>, <G11 4.2>, <D9 41.5>, <E8 0.0>, <F5 3567.0>, <D5 1032.0>, <I11 0.0>, <F8 172.0>, <H6 650.0>, <B11 0.3>, <F10 30.0>, <G5 4095.0>, <M5 1874.0>, <G7 1501.0>, <L10 31.8>, <I9 71.7>, <D10 42.3>, <F11 4.8>, <I8 0.0>, <J10 53.1>, <I7 153.0>, <G9 59.1>, <E11 0.0>, <D8 167.0>, <D6 428.0>, <L9 67.7>, <M8 11.0>, <J11 3.4>, <J8 11.0>, <B10 31.5>, <E10 81.8>, <E6 96.0>, <F7 1069.0>, <M9 62.9>, <M7 685.0>, <H8 0.0>, <B6 1069.0>, <I10 28.3>, <K5 185.0>, <J7 172.0>, <C8 0.0>, <H11 0.0>, <C10 38.2>, <H7 360.0>, <M10 36.6>, <F6 2326.0>, <D11 16.2>, <B9 68.2>, <G6 2422.0>, <I6 387.0>, <K11 0.6>, <G10 36.7>, <K8 11.0>, <E7 432.0>, <F9 65.2>, <J5 324.0>}

# %%
Service = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Service
# Out:
# {<A13 'Service Type'>, <A11 'Prison (%)'>, <A18 'Prison'>, <A6 'Statutory'>, <A9 'Statutory (%)'>, <A15 'Total'>, <A10 'Non-statutory (%)'>, <A7 'Non-statutory'>, <A8 'Prison'>, <A17 'Non-statutory'>, <A19 'Statutory (%)'>, <A5 'Total'>, <A16 'Statutory'>, <A20 'Non-statutory (%)'>, <A21 'Prison (%)'>}

# %%
Treatment = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Treatment
# Out:
# {<L4 '18 and over'>, <M4 'Total'>, <J4 'Drugs & Alcohol'>, <B4 'Alcohol Only'>, <I4 'Drugs Only'>, <C4 'Drugs Only'>, <F4 '18 and over'>, <K4 'Under 18s'>, <D4 'Drugs & Alcohol'>, <G4 'Total'>, <E4 'Under 18s'>, <H4 'Alcohol Only'>}

# %%
sex = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
sex
# Out:
# {<H3 'Female  '>, <B3 'Male'>}

# %%
Dimensions = [
            HDim(Treatment,'Treatment Type',DIRECTLY,ABOVE),
            HDim(Service,'Service Type',DIRECTLY,LEFT),
            HDim(sex,'Sex',CLOSEST,LEFT),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People'),
            HDimConst('Period','1 March 2017'),
            HDimConst('Age','All')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS   Treatment Type       Service Type       Sex Measure Type    Unit  \
# 0   1567.0     Alcohol Only              Total      Male        Count  People
# 1   1496.0       Drugs Only              Total      Male        Count  People
# 2   1032.0  Drugs & Alcohol              Total      Male        Count  People
# 3    528.0        Under 18s              Total      Male        Count  People
# 4   3567.0      18 and over              Total      Male        Count  People
# 5   4095.0            Total              Total      Male        Count  People
# 6   1010.0     Alcohol Only              Total  Female          Count  People
# 7    540.0       Drugs Only              Total  Female          Count  People
# 8    324.0  Drugs & Alcohol              Total  Female          Count  People
# 9    185.0        Under 18s              Total  Female          Count  People
# 10  1689.0      18 and over              Total  Female          Count  People
# 11  1874.0            Total              Total  Female          Count  People
# 12  1069.0     Alcohol Only          Statutory      Male        Count  People
# 13   925.0       Drugs Only          Statutory      Male        Count  People
# 14   428.0  Drugs & Alcohol          Statutory      Male        Count  People
# 15    96.0        Under 18s          Statutory      Male        Count  People
# 16  2326.0      18 and over          Statutory      Male        Count  People
# 17  2422.0            Total          Statutory      Male        Count  People
# 18   650.0     Alcohol Only          Statutory  Female          Count  People
# 19   387.0       Drugs Only          Statutory  Female          Count  People
# 20   141.0  Drugs & Alcohol          Statutory  Female          Count  People
# 21    35.0        Under 18s          Statutory  Female          Count  People
# 22  1143.0      18 and over          Statutory  Female          Count  People
# 23  1178.0            Total          Statutory  Female          Count  People
# 24   493.0     Alcohol Only      Non-statutory      Male        Count  People
# 25   571.0       Drugs Only      Non-statutory      Male        Count  People
# 26   437.0  Drugs & Alcohol      Non-statutory      Male        Count  People
# 27   432.0        Under 18s      Non-statutory      Male        Count  People
# 28  1069.0      18 and over      Non-statutory      Male        Count  People
# 29  1501.0            Total      Non-statutory      Male        Count  People
# ..     ...              ...                ...       ...          ...     ...
# 52    59.1            Total      Statutory (%)      Male        Count  People
# 53    64.4     Alcohol Only      Statutory (%)  Female          Count  People
# 54    71.7       Drugs Only      Statutory (%)  Female          Count  People
# 55    43.5  Drugs & Alcohol      Statutory (%)  Female          Count  People
# 56    18.9        Under 18s      Statutory (%)  Female          Count  People
# 57    67.7      18 and over      Statutory (%)  Female          Count  People
# 58    62.9            Total      Statutory (%)  Female          Count  People
# 59    31.5     Alcohol Only  Non-statutory (%)      Male        Count  People
# 60    38.2       Drugs Only  Non-statutory (%)      Male        Count  People
# 61    42.3  Drugs & Alcohol  Non-statutory (%)      Male        Count  People
# 62    81.8        Under 18s  Non-statutory (%)      Male        Count  People
# 63    30.0      18 and over  Non-statutory (%)      Male        Count  People
# 64    36.7            Total  Non-statutory (%)      Male        Count  People
# 65    35.6     Alcohol Only  Non-statutory (%)  Female          Count  People
# 66    28.3       Drugs Only  Non-statutory (%)  Female          Count  People
# 67    53.1  Drugs & Alcohol  Non-statutory (%)  Female          Count  People
# 68    80.0        Under 18s  Non-statutory (%)  Female          Count  People
# 69    31.8      18 and over  Non-statutory (%)  Female          Count  People
# 70    36.6            Total  Non-statutory (%)  Female          Count  People
# 71     0.3     Alcohol Only         Prison (%)      Male        Count  People
# 72     0.0       Drugs Only         Prison (%)      Male        Count  People
# 73    16.2  Drugs & Alcohol         Prison (%)      Male        Count  People
# 74     0.0        Under 18s         Prison (%)      Male        Count  People
# 75     4.8      18 and over         Prison (%)      Male        Count  People
# 76     4.2            Total         Prison (%)      Male        Count  People
# 77     0.0     Alcohol Only         Prison (%)  Female          Count  People
# 78     0.0       Drugs Only         Prison (%)  Female          Count  People
# 79     3.4  Drugs & Alcohol         Prison (%)  Female          Count  People
# 80     0.6        Under 18s         Prison (%)  Female          Count  People
# 81     0.6            Total         Prison (%)  Female          Count  People
#
#           Period  Age
# 0   1 March 2017  All
# 1   1 March 2017  All
# 2   1 March 2017  All
# 3   1 March 2017  All
# 4   1 March 2017  All
# 5   1 March 2017  All
# 6   1 March 2017  All
# 7   1 March 2017  All
# 8   1 March 2017  All
# 9   1 March 2017  All
# 10  1 March 2017  All
# 11  1 March 2017  All
# 12  1 March 2017  All
# 13  1 March 2017  All
# 14  1 March 2017  All
# 15  1 March 2017  All
# 16  1 March 2017  All
# 17  1 March 2017  All
# 18  1 March 2017  All
# 19  1 March 2017  All
# 20  1 March 2017  All
# 21  1 March 2017  All
# 22  1 March 2017  All
# 23  1 March 2017  All
# 24  1 March 2017  All
# 25  1 March 2017  All
# 26  1 March 2017  All
# 27  1 March 2017  All
# 28  1 March 2017  All
# 29  1 March 2017  All
# ..           ...  ...
# 52  1 March 2017  All
# 53  1 March 2017  All
# 54  1 March 2017  All
# 55  1 March 2017  All
# 56  1 March 2017  All
# 57  1 March 2017  All
# 58  1 March 2017  All
# 59  1 March 2017  All
# 60  1 March 2017  All
# 61  1 March 2017  All
# 62  1 March 2017  All
# 63  1 March 2017  All
# 64  1 March 2017  All
# 65  1 March 2017  All
# 66  1 March 2017  All
# 67  1 March 2017  All
# 68  1 March 2017  All
# 69  1 March 2017  All
# 70  1 March 2017  All
# 71  1 March 2017  All
# 72  1 March 2017  All
# 73  1 March 2017  All
# 74  1 March 2017  All
# 75  1 March 2017  All
# 76  1 March 2017  All
# 77  1 March 2017  All
# 78  1 March 2017  All
# 79  1 March 2017  All
# 80  1 March 2017  All
# 81  1 March 2017  All
#
# [82 rows x 8 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.dtypes
# Out:
# Value             float64
# Treatment Type     object
# Service Type       object
# Sex                object
# Measure Type       object
# Unit               object
# Period             object
# Age                object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value   Treatment Type Service Type       Sex Measure Type    Unit  \
# 77    0.0     Alcohol Only   Prison (%)  Female          Count  People
# 78    0.0       Drugs Only   Prison (%)  Female          Count  People
# 79    3.4  Drugs & Alcohol   Prison (%)  Female          Count  People
# 80    0.6        Under 18s   Prison (%)  Female          Count  People
# 81    0.6            Total   Prison (%)  Female          Count  People
#
#           Period  Age
# 77  1 March 2017  All
# 78  1 March 2017  All
# 79  1 March 2017  All
# 80  1 March 2017  All
# 81  1 March 2017  All

# %%
new_table.count()
# Out:
# Value             82
# Treatment Type    82
# Service Type      82
# Sex               82
# Measure Type      82
# Unit              82
# Period            82
# Age               82
# dtype: int64

# %%
new_table = new_table[new_table['Value'] !=  0 ]

# %%
new_table.count()
# Out:
# Value             74
# Treatment Type    74
# Service Type      74
# Sex               74
# Measure Type      74
# Unit              74
# Period            74
# Age               74
# dtype: int64

# %%
new_table['Treatment Type'].fillna('All', inplace = True)
# new_table['Service Type'] = 'All'
new_table['Residential Status'] = 'All'
new_table['Health and Social Care Trust']  = 'All'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# 2   Drugs & Alcohol                          All        Count  People  1032.0
# 3         Under 18s                          All        Count  People   528.0
# 4       18 and over                          All        Count  People  3567.0
# 5             Total                          All        Count  People  4095.0
# 6      Alcohol Only                          All        Count  People  1010.0
# 7        Drugs Only                          All        Count  People   540.0
# 8   Drugs & Alcohol                          All        Count  People   324.0
# 9         Under 18s                          All        Count  People   185.0
# 10      18 and over                          All        Count  People  1689.0
# 11            Total                          All        Count  People  1874.0
# 12     Alcohol Only                          All        Count  People  1069.0
# 13       Drugs Only                          All        Count  People   925.0
# 14  Drugs & Alcohol                          All        Count  People   428.0
# 15        Under 18s                          All        Count  People    96.0
# 16      18 and over                          All        Count  People  2326.0
# 17            Total                          All        Count  People  2422.0
# 18     Alcohol Only                          All        Count  People   650.0
# 19       Drugs Only                          All        Count  People   387.0
# 20  Drugs & Alcohol                          All        Count  People   141.0
# 21        Under 18s                          All        Count  People    35.0
# 22      18 and over                          All        Count  People  1143.0
# 23            Total                          All        Count  People  1178.0
# 24     Alcohol Only                          All        Count  People   493.0
# 25       Drugs Only                          All        Count  People   571.0
# 26  Drugs & Alcohol                          All        Count  People   437.0
# 27        Under 18s                          All        Count  People   432.0
# 28      18 and over                          All        Count  People  1069.0
# 29            Total                          All        Count  People  1501.0
# ..              ...                          ...          ...     ...     ...
# 48       Drugs Only                          All        Count  People    61.8
# 49  Drugs & Alcohol                          All        Count  People    41.5
# 50        Under 18s                          All        Count  People    18.2
# 51      18 and over                          All        Count  People    65.2
# 52            Total                          All        Count  People    59.1
# 53     Alcohol Only                          All        Count  People    64.4
# 54       Drugs Only                          All        Count  People    71.7
# 55  Drugs & Alcohol                          All        Count  People    43.5
# 56        Under 18s                          All        Count  People    18.9
# 57      18 and over                          All        Count  People    67.7
# 58            Total                          All        Count  People    62.9
# 59     Alcohol Only                          All        Count  People    31.5
# 60       Drugs Only                          All        Count  People    38.2
# 61  Drugs & Alcohol                          All        Count  People    42.3
# 62        Under 18s                          All        Count  People    81.8
# 63      18 and over                          All        Count  People    30.0
# 64            Total                          All        Count  People    36.7
# 65     Alcohol Only                          All        Count  People    35.6
# 66       Drugs Only                          All        Count  People    28.3
# 67  Drugs & Alcohol                          All        Count  People    53.1
# 68        Under 18s                          All        Count  People    80.0
# 69      18 and over                          All        Count  People    31.8
# 70            Total                          All        Count  People    36.6
# 71     Alcohol Only                          All        Count  People     0.3
# 73  Drugs & Alcohol                          All        Count  People    16.2
# 75      18 and over                          All        Count  People     4.8
# 76            Total                          All        Count  People     4.2
# 79  Drugs & Alcohol                          All        Count  People     3.4
# 80        Under 18s                          All        Count  People     0.6
# 81            Total                          All        Count  People     0.6
#
# [74 rows x 10 columns]

# %%
new_table.tail()
# Out:
#           Period       Sex  Age Service Type Residential Status  \
# 75  1 March 2017      Male  All   Prison (%)                All
# 76  1 March 2017      Male  All   Prison (%)                All
# 79  1 March 2017  Female    All   Prison (%)                All
# 80  1 March 2017  Female    All   Prison (%)                All
# 81  1 March 2017  Female    All   Prison (%)                All
#
#      Treatment Type Health and Social Care Trust Measure Type    Unit  Value
# 75      18 and over                          All        Count  People    4.8
# 76            Total                          All        Count  People    4.2
# 79  Drugs & Alcohol                          All        Count  People    3.4
# 80        Under 18s                          All        Count  People    0.6
# 81            Total                          All        Count  People    0.6
